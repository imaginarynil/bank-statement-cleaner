# %% [markdown]
# ## Create

# %%
import re
import pandas as pd
import numpy as np
import os

# %%
dir_path = "C:/Users/Daniel/Documents/Git/bank-statement-cleaner/synthetic_data"
savings_csv_path = os.path.join(dir_path, "savings.csv")
chequing_csv_path = os.path.join(dir_path, "chequing.csv")
credit_csv_path = os.path.join(dir_path, "credit.csv")

# %%
class CIBCTransactionDescription:
    def __init__(
        self,
        method="",
        type="",
        party=""
    ):
        self.method = method
        self.type = type
        self.party = party

    def to_pd_series(self):
        # convert to lower case to make queries easier
        attributes = [
            self.method,
            self.type,
            self.party
        ]
        for i in range(0, len(attributes)):
            if not attributes[i]:
                attributes[i] = np.nan
            else:
                attributes[i] = attributes[i].lower()
        return pd.Series(attributes)

# %%
def parse_debit_description(description):
    tx_type_match = re.search(r'[A-Z][^a-z0-9]*[A-Z]', description) # get transaction type
    if not tx_type_match:
        return CIBCTransactionDescription().to_pd_series()
    tx_type = tx_type_match.group()
    tx_method = description[:tx_type_match.span()[0] - 1]
    for word in [
        "CHARGE",
        "CORRECTION",
        "DEPOSIT",
        "FEE",
        "INTEREST",
        "MEMO",
        "PAY",
        "PURCHASE",
        "TRANSFER",
    ]:
        word_start_index = tx_type.rfind(word) # scan from right
        if word_start_index == -1:
            continue
        tx_type = tx_type[:word_start_index + len(word)]
        # special case for service charges
        if word == "CHARGE":
            return CIBCTransactionDescription(
                method=tx_method,
                type=tx_type
            ).to_pd_series()
        break
    tx_type_end_index = tx_type_match.span()[0] + len(tx_type) - 1
    if tx_type_end_index == len(description) - 1:
        return CIBCTransactionDescription(
            method=tx_method,
            type=tx_type
        ).to_pd_series()
    remainder = description[tx_type_end_index + 2:]
    remainder = remainder.replace("*", "") # delete asterisks
    # find a token with only letters and numbers with at least 1 letter and 1 number
    for token in remainder.split(" "):
        if re.search("^[0-9A-Z]+$", token) and re.search("[0-9]", token) and re.search("[A-Z]", token):
            return CIBCTransactionDescription(
                    method=tx_method,
                    type=tx_type,
                    party=remainder.replace(token, "").strip()
                ).to_pd_series()
    # find a token with only numbers
    token_match = re.search("^[0-9]+(?= )|(?<= )[0-9]+$|(?<= )[0-9]+(?= )", remainder)
    if token_match:
        return CIBCTransactionDescription(
            method=tx_method,
            type=tx_type,
            party=remainder.replace(token_match.group(), "").strip()
        ).to_pd_series()
    return CIBCTransactionDescription(
        method=tx_method,
        type=tx_type
    ).to_pd_series()

# %%
def expand_debit(df):
    df[["method", "type", "party"]] = df["description"].apply(parse_debit_description)

# %%
def parse_credit_description(description):
    tx_location_match = re.search(r'[^ ]+, .+$', description) # get transaction location
    if not tx_location_match:
        return np.nan
    return description.replace(tx_location_match.group(), "").strip().lower()

# %%
def expand_credit(df):
    df["party"] = df["description"].apply(parse_credit_description)

# %%
def expand_account_df(account, account_df, expand_fn=None, duplicate_index=True):
    df = account_df.copy()
    date = pd.to_datetime(df["date"])
    df["date"] = date.dt.strftime("%Y-%m-%d")
    df["year"] = date.dt.year
    df["month"] = date.dt.month
    df["day"] = date.dt.day
    df["account"] = account
    df["amount"] = df[["debit", "credit"]].apply(lambda x: x["credit"] if pd.isnull(x["debit"]) else -1 * x["debit"], axis=1)
    df = df.drop(columns=["debit", "credit"])
    if expand_fn:
        expand_fn(df)
    if duplicate_index:
        df["index_copy"] = df.index
    return df

# %%
savings_df = pd.read_csv(savings_csv_path, names=["date", "description", "debit", "credit"])
savings_df
# Out:
#           date                                        description   debit  \
# 0   2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO     NaN
# 1   2025-01-31  Internet Banking E-TRANSFER 497466188861 LANDLORD  1500.0
# 2   2025-01-31  Internet Banking E-TRANSFER 023468170802 LANDLORD   283.0
# 3   2025-01-31   Internet Banking INTERNET TRANSFER 125959237893      NaN
# 4   2025-02-28  Internet Banking E-TRANSFER 233755062894 LANDLORD  1500.0
# 5   2025-02-28  Internet Banking E-TRANSFER 307059499977 LANDLORD   277.0
# 6   2025-02-28   Internet Banking INTERNET TRANSFER 302543818917      NaN
# 7   2025-03-31   Internet Banking INTERNET TRANSFER 838173975039      NaN
# 8   2025-03-31  Internet Banking E-TRANSFER 410913019913 LANDLORD   284.0
# 9   2025-03-31  Internet Banking E-TRANSFER 528426674492 LANDLORD  1500.0
# 10  2025-04-30  Internet Banking E-TRANSFER 829120631610 LANDLORD  1500.0
# 11  2025-04-30  Internet Banking E-TRANSFER 200541329033 LANDLORD   291.0
# 12  2025-04-30   Internet Banking INTERNET TRANSFER 732015329788      NaN
# 13  2025-05-31  Internet Banking E-TRANSFER 625353525455 LANDLORD  1500.0
# 14  2025-05-31  Internet Banking E-TRANSFER 513036925420 LANDLORD   294.0
# 15  2025-05-31   Internet Banking INTERNET TRANSFER 199266785895      NaN
# 16  2025-06-30  Internet Banking E-TRANSFER 966334448033 LANDLORD   264.0
# 17  2025-06-30   Internet Banking INTERNET TRANSFER 647328542519      NaN
# 18  2025-06-30  Internet Banking E-TRANSFER 546538355224 LANDLORD  1500.0
# 19  2025-07-31  Internet Banking E-TRANSFER 875882121947 LANDLORD  1500.0
# 20  2025-07-31  Internet Banking E-TRANSFER 130782139534 LANDLORD   268.0
# 21  2025-07-31   Internet Banking INTERNET TRANSFER 224938125884      NaN
# 22  2025-08-31  Internet Banking E-TRANSFER 252841963626 LANDLORD  1500.0
# 23  2025-08-31  Internet Banking E-TRANSFER 773497235500 LANDLORD   253.0
# 24  2025-08-31   Internet Banking INTERNET TRANSFER 213841671997      NaN
# 25  2025-09-30   Internet Banking INTERNET TRANSFER 055336254384      NaN
# 26  2025-09-30  Internet Banking E-TRANSFER 515191359104 LANDLORD  1500.0
# 27  2025-09-30  Internet Banking E-TRANSFER 089744038644 LANDLORD   261.0
# 28  2025-10-31  Internet Banking E-TRANSFER 176098198763 LANDLORD  1500.0
# 29  2025-10-31  Internet Banking E-TRANSFER 166437367261 LANDLORD   277.0
# 30  2025-10-31   Internet Banking INTERNET TRANSFER 576395623352      NaN
# 31  2025-11-30  Internet Banking E-TRANSFER 642949362465 LANDLORD  1500.0
# 32  2025-11-30  Internet Banking E-TRANSFER 595706408477 LANDLORD   286.0
# 33  2025-11-30   Internet Banking INTERNET TRANSFER 217777030307      NaN
# 34  2025-12-31  Internet Banking E-TRANSFER 103978351491 LANDLORD   279.0
# 35  2025-12-31  Internet Banking E-TRANSFER 181227351012 LANDLORD  1500.0
# 36  2025-12-31   Internet Banking INTERNET TRANSFER 794179128749      NaN
#
#      credit
# 0    2000.0
# 1       NaN
# 2       NaN
# 3   50000.0
# 4       NaN
# 5       NaN
# 6   50000.0
# 7   50000.0
# 8       NaN
# 9       NaN
# 10      NaN
# 11      NaN
# 12  50000.0
# 13      NaN
# 14      NaN
# 15  50000.0
# 16      NaN
# 17  50000.0
# 18      NaN
# 19      NaN
# 20      NaN
# 21  50000.0
# 22      NaN
# 23      NaN
# 24  50000.0
# 25  50000.0
# 26      NaN
# 27      NaN
# 28      NaN
# 29      NaN
# 30  50000.0
# 31      NaN
# 32      NaN
# 33  50000.0
# 34      NaN
# 35      NaN
# 36  50000.0

# %%
expanded_savings_df = expand_account_df("savings", savings_df, expand_fn=expand_debit)
expanded_savings_df
# Out:
#           date                                        description  year  \
# 0   2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 1   2025-01-31  Internet Banking E-TRANSFER 497466188861 LANDLORD  2025
# 2   2025-01-31  Internet Banking E-TRANSFER 023468170802 LANDLORD  2025
# 3   2025-01-31   Internet Banking INTERNET TRANSFER 125959237893   2025
# 4   2025-02-28  Internet Banking E-TRANSFER 233755062894 LANDLORD  2025
# 5   2025-02-28  Internet Banking E-TRANSFER 307059499977 LANDLORD  2025
# 6   2025-02-28   Internet Banking INTERNET TRANSFER 302543818917   2025
# 7   2025-03-31   Internet Banking INTERNET TRANSFER 838173975039   2025
# 8   2025-03-31  Internet Banking E-TRANSFER 410913019913 LANDLORD  2025
# 9   2025-03-31  Internet Banking E-TRANSFER 528426674492 LANDLORD  2025
# 10  2025-04-30  Internet Banking E-TRANSFER 829120631610 LANDLORD  2025
# 11  2025-04-30  Internet Banking E-TRANSFER 200541329033 LANDLORD  2025
# 12  2025-04-30   Internet Banking INTERNET TRANSFER 732015329788   2025
# 13  2025-05-31  Internet Banking E-TRANSFER 625353525455 LANDLORD  2025
# 14  2025-05-31  Internet Banking E-TRANSFER 513036925420 LANDLORD  2025
# 15  2025-05-31   Internet Banking INTERNET TRANSFER 199266785895   2025
# 16  2025-06-30  Internet Banking E-TRANSFER 966334448033 LANDLORD  2025
# 17  2025-06-30   Internet Banking INTERNET TRANSFER 647328542519   2025
# 18  2025-06-30  Internet Banking E-TRANSFER 546538355224 LANDLORD  2025
# 19  2025-07-31  Internet Banking E-TRANSFER 875882121947 LANDLORD  2025
# 20  2025-07-31  Internet Banking E-TRANSFER 130782139534 LANDLORD  2025
# 21  2025-07-31   Internet Banking INTERNET TRANSFER 224938125884   2025
# 22  2025-08-31  Internet Banking E-TRANSFER 252841963626 LANDLORD  2025
# 23  2025-08-31  Internet Banking E-TRANSFER 773497235500 LANDLORD  2025
# 24  2025-08-31   Internet Banking INTERNET TRANSFER 213841671997   2025
# 25  2025-09-30   Internet Banking INTERNET TRANSFER 055336254384   2025
# 26  2025-09-30  Internet Banking E-TRANSFER 515191359104 LANDLORD  2025
# 27  2025-09-30  Internet Banking E-TRANSFER 089744038644 LANDLORD  2025
# 28  2025-10-31  Internet Banking E-TRANSFER 176098198763 LANDLORD  2025
# 29  2025-10-31  Internet Banking E-TRANSFER 166437367261 LANDLORD  2025
# 30  2025-10-31   Internet Banking INTERNET TRANSFER 576395623352   2025
# 31  2025-11-30  Internet Banking E-TRANSFER 642949362465 LANDLORD  2025
# 32  2025-11-30  Internet Banking E-TRANSFER 595706408477 LANDLORD  2025
# 33  2025-11-30   Internet Banking INTERNET TRANSFER 217777030307   2025
# 34  2025-12-31  Internet Banking E-TRANSFER 103978351491 LANDLORD  2025
# 35  2025-12-31  Internet Banking E-TRANSFER 181227351012 LANDLORD  2025
# 36  2025-12-31   Internet Banking INTERNET TRANSFER 794179128749   2025
#
#     month  day  account   amount                     method  \
# 0       1    1  savings   2000.0  automated banking machine
# 1       1   31  savings  -1500.0           internet banking
# 2       1   31  savings   -283.0           internet banking
# 3       1   31  savings  50000.0           internet banking
# 4       2   28  savings  -1500.0           internet banking
# 5       2   28  savings   -277.0           internet banking
# 6       2   28  savings  50000.0           internet banking
# 7       3   31  savings  50000.0           internet banking
# 8       3   31  savings   -284.0           internet banking
# 9       3   31  savings  -1500.0           internet banking
# 10      4   30  savings  -1500.0           internet banking
# 11      4   30  savings   -291.0           internet banking
# 12      4   30  savings  50000.0           internet banking
# 13      5   31  savings  -1500.0           internet banking
# 14      5   31  savings   -294.0           internet banking
# 15      5   31  savings  50000.0           internet banking
# 16      6   30  savings   -264.0           internet banking
# 17      6   30  savings  50000.0           internet banking
# 18      6   30  savings  -1500.0           internet banking
# 19      7   31  savings  -1500.0           internet banking
# 20      7   31  savings   -268.0           internet banking
# 21      7   31  savings  50000.0           internet banking
# 22      8   31  savings  -1500.0           internet banking
# 23      8   31  savings   -253.0           internet banking
# 24      8   31  savings  50000.0           internet banking
# 25      9   30  savings  50000.0           internet banking
# 26      9   30  savings  -1500.0           internet banking
# 27      9   30  savings   -261.0           internet banking
# 28     10   31  savings  -1500.0           internet banking
# 29     10   31  savings   -277.0           internet banking
# 30     10   31  savings  50000.0           internet banking
# 31     11   30  savings  -1500.0           internet banking
# 32     11   30  savings   -286.0           internet banking
# 33     11   30  savings  50000.0           internet banking
# 34     12   31  savings   -279.0           internet banking
# 35     12   31  savings  -1500.0           internet banking
# 36     12   31  savings  50000.0           internet banking
#
#                  type     party  index_copy
# 0         atm deposit       NaN           0
# 1          e-transfer  landlord           1
# 2          e-transfer  landlord           2
# 3   internet transfer       NaN           3
# 4          e-transfer  landlord           4
# 5          e-transfer  landlord           5
# 6   internet transfer       NaN           6
# 7   internet transfer       NaN           7
# 8          e-transfer  landlord           8
# 9          e-transfer  landlord           9
# 10         e-transfer  landlord          10
# 11         e-transfer  landlord          11
# 12  internet transfer       NaN          12
# 13         e-transfer  landlord          13
# 14         e-transfer  landlord          14
# 15  internet transfer       NaN          15
# 16         e-transfer  landlord          16
# 17  internet transfer       NaN          17
# 18         e-transfer  landlord          18
# 19         e-transfer  landlord          19
# 20         e-transfer  landlord          20
# 21  internet transfer       NaN          21
# 22         e-transfer  landlord          22
# 23         e-transfer  landlord          23
# 24  internet transfer       NaN          24
# 25  internet transfer       NaN          25
# 26         e-transfer  landlord          26
# 27         e-transfer  landlord          27
# 28         e-transfer  landlord          28
# 29         e-transfer  landlord          29
# 30  internet transfer       NaN          30
# 31         e-transfer  landlord          31
# 32         e-transfer  landlord          32
# 33  internet transfer       NaN          33
# 34         e-transfer  landlord          34
# 35         e-transfer  landlord          35
# 36  internet transfer       NaN          36

# %%
chequing_df = pd.read_csv(chequing_csv_path, names=["date", "description", "debit", "credit"])
chequing_df
# Out:
#            date                                        description    debit  \
# 0    2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO      NaN
# 1    2025-01-01  Internet Banking E-TRANSFER 198387442408 BLUE ...     50.0
# 2    2025-01-02  Point of Sale - Interac RETAIL PURCHASE 739855...     16.0
# 3    2025-01-02  Point of Sale - Visa Debit VISA DEBIT RETAIL P...      3.0
# 4    2025-01-03  Point of Sale - Visa Debit VISA DEBIT RETAIL P...     10.0
# ..          ...                                                ...      ...
# 416  2025-12-01  Internet Banking E-TRANSFER 510912177359 BLUE ...     50.0
# 417  2025-12-02   Internet Banking INTERNET TRANSFER 872872991979      54.0
# 418  2025-12-02  Point of Sale - Interac RETAIL PURCHASE 925576...     16.0
# 419  2025-12-31   Internet Banking INTERNET TRANSFER 794179128749   50000.0
# 420  2025-12-31                    Branch Transaction CREDIT MEMO       NaN
#
#      credit
# 0    2000.0
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 416     NaN
# 417     NaN
# 418     NaN
# 419     NaN
# 420  7000.0
#
# [421 rows x 4 columns]

# %%
expanded_chequing_df = expand_account_df("chequing", chequing_df, expand_fn=expand_debit)
expanded_chequing_df
# Out:
#            date                                        description  year  \
# 0    2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 1    2025-01-01  Internet Banking E-TRANSFER 198387442408 BLUE ...  2025
# 2    2025-01-02  Point of Sale - Interac RETAIL PURCHASE 739855...  2025
# 3    2025-01-02  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# 4    2025-01-03  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# ..          ...                                                ...   ...
# 416  2025-12-01  Internet Banking E-TRANSFER 510912177359 BLUE ...  2025
# 417  2025-12-02   Internet Banking INTERNET TRANSFER 872872991979   2025
# 418  2025-12-02  Point of Sale - Interac RETAIL PURCHASE 925576...  2025
# 419  2025-12-31   Internet Banking INTERNET TRANSFER 794179128749   2025
# 420  2025-12-31                    Branch Transaction CREDIT MEMO   2025
#
#      month  day   account   amount                      method  \
# 0        1    1  chequing   2000.0   automated banking machine
# 1        1    1  chequing    -50.0            internet banking
# 2        1    2  chequing    -16.0     point of sale - interac
# 3        1    2  chequing     -3.0  point of sale - visa debit
# 4        1    3  chequing    -10.0  point of sale - visa debit
# ..     ...  ...       ...      ...                         ...
# 416     12    1  chequing    -50.0            internet banking
# 417     12    2  chequing    -54.0            internet banking
# 418     12    2  chequing    -16.0     point of sale - interac
# 419     12   31  chequing -50000.0            internet banking
# 420     12   31  chequing   7000.0          branch transaction
#
#                            type             party  index_copy
# 0                   atm deposit               NaN           0
# 1                    e-transfer  blue hockey club           1
# 2               retail purchase             pizza           2
# 3    visa debit retail purchase            presto           3
# 4    visa debit retail purchase            presto           4
# ..                          ...               ...         ...
# 416                  e-transfer  blue hockey club         416
# 417           internet transfer               NaN         417
# 418             retail purchase             pizza         418
# 419           internet transfer               NaN         419
# 420                 credit memo               NaN         420
#
# [421 rows x 11 columns]

# %%
def load_cibc_credit_csv(csv_path):
    credit_df = pd.read_csv(csv_path, usecols=range(0, 4), names=["date", "description", "debit", "credit"])
    return credit_df

# %%
credit_df = load_cibc_credit_csv(credit_csv_path)
credit_df
# Out:
#           date                        description  debit  credit
# 0   2025-01-07                WALMART TORONTO, ON   78.0     NaN
# 1   2025-01-07  PAYMENT THANK YOU/PAIEMEN T MERCI    NaN    78.0
# 2   2025-01-14                WALMART TORONTO, ON   65.0     NaN
# 3   2025-01-14  PAYMENT THANK YOU/PAIEMEN T MERCI    NaN    65.0
# 4   2025-01-21                WALMART TORONTO, ON   92.0     NaN
# ..         ...                                ...    ...     ...
# 91  2025-11-18  PAYMENT THANK YOU/PAIEMEN T MERCI    NaN    60.0
# 92  2025-11-25                WALMART TORONTO, ON   83.0     NaN
# 93  2025-11-25  PAYMENT THANK YOU/PAIEMEN T MERCI    NaN    83.0
# 94  2025-12-02                WALMART TORONTO, ON   54.0     NaN
# 95  2025-12-02  PAYMENT THANK YOU/PAIEMEN T MERCI    NaN    54.0
#
# [96 rows x 4 columns]

# %%
expanded_credit_df = expand_account_df(
    "credit",
    credit_df,
    expand_fn=expand_credit,
    duplicate_index=False
)
expanded_credit_df
# Out:
#           date                        description  year  month  day account  \
# 0   2025-01-07                WALMART TORONTO, ON  2025      1    7  credit
# 1   2025-01-07  PAYMENT THANK YOU/PAIEMEN T MERCI  2025      1    7  credit
# 2   2025-01-14                WALMART TORONTO, ON  2025      1   14  credit
# 3   2025-01-14  PAYMENT THANK YOU/PAIEMEN T MERCI  2025      1   14  credit
# 4   2025-01-21                WALMART TORONTO, ON  2025      1   21  credit
# ..         ...                                ...   ...    ...  ...     ...
# 91  2025-11-18  PAYMENT THANK YOU/PAIEMEN T MERCI  2025     11   18  credit
# 92  2025-11-25                WALMART TORONTO, ON  2025     11   25  credit
# 93  2025-11-25  PAYMENT THANK YOU/PAIEMEN T MERCI  2025     11   25  credit
# 94  2025-12-02                WALMART TORONTO, ON  2025     12    2  credit
# 95  2025-12-02  PAYMENT THANK YOU/PAIEMEN T MERCI  2025     12    2  credit
#
#     amount    party
# 0    -78.0  walmart
# 1     78.0      NaN
# 2    -65.0  walmart
# 3     65.0      NaN
# 4    -92.0  walmart
# ..     ...      ...
# 91    60.0      NaN
# 92   -83.0  walmart
# 93    83.0      NaN
# 94   -54.0  walmart
# 95    54.0      NaN
#
# [96 rows x 8 columns]

# %%
def create_indexed_df(dataframes):
    df = pd.concat(dataframes).sort_values(by=["date"])
    df["uid"] = df.reset_index(drop=True).index + 1
    return df

# %%
combined_expanded_df = create_indexed_df([
    expanded_savings_df,
    expanded_chequing_df,
    expanded_credit_df
])
combined_expanded_df
# Out:
#            date                                        description  year  \
# 0    2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 1    2025-01-01  Internet Banking E-TRANSFER 198387442408 BLUE ...  2025
# 0    2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 3    2025-01-02  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# 2    2025-01-02  Point of Sale - Interac RETAIL PURCHASE 739855...  2025
# ..          ...                                                ...   ...
# 419  2025-12-31   Internet Banking INTERNET TRANSFER 794179128749   2025
# 420  2025-12-31                    Branch Transaction CREDIT MEMO   2025
# 36   2025-12-31   Internet Banking INTERNET TRANSFER 794179128749   2025
# 35   2025-12-31  Internet Banking E-TRANSFER 181227351012 LANDLORD  2025
# 34   2025-12-31  Internet Banking E-TRANSFER 103978351491 LANDLORD  2025
#
#      month  day   account   amount                      method  \
# 0        1    1   savings   2000.0   automated banking machine
# 1        1    1  chequing    -50.0            internet banking
# 0        1    1  chequing   2000.0   automated banking machine
# 3        1    2  chequing     -3.0  point of sale - visa debit
# 2        1    2  chequing    -16.0     point of sale - interac
# ..     ...  ...       ...      ...                         ...
# 419     12   31  chequing -50000.0            internet banking
# 420     12   31  chequing   7000.0          branch transaction
# 36      12   31   savings  50000.0            internet banking
# 35      12   31   savings  -1500.0            internet banking
# 34      12   31   savings   -279.0            internet banking
#
#                            type             party  index_copy  uid
# 0                   atm deposit               NaN         0.0    1
# 1                    e-transfer  blue hockey club         1.0    2
# 0                   atm deposit               NaN         0.0    3
# 3    visa debit retail purchase            presto         3.0    4
# 2               retail purchase             pizza         2.0    5
# ..                          ...               ...         ...  ...
# 419           internet transfer               NaN       419.0  550
# 420                 credit memo               NaN       420.0  551
# 36            internet transfer               NaN        36.0  552
# 35                   e-transfer          landlord        35.0  553
# 34                   e-transfer          landlord        34.0  554
#
# [554 rows x 12 columns]

# %%
expanded_savings_df = expanded_savings_df.sort_index()
expanded_savings_df["uid"] = combined_expanded_df.loc[combined_expanded_df["account"] == "savings"].sort_index()["uid"]
expanded_savings_df
# Out:
#           date                                        description  year  \
# 0   2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 1   2025-01-31  Internet Banking E-TRANSFER 497466188861 LANDLORD  2025
# 2   2025-01-31  Internet Banking E-TRANSFER 023468170802 LANDLORD  2025
# 3   2025-01-31   Internet Banking INTERNET TRANSFER 125959237893   2025
# 4   2025-02-28  Internet Banking E-TRANSFER 233755062894 LANDLORD  2025
# 5   2025-02-28  Internet Banking E-TRANSFER 307059499977 LANDLORD  2025
# 6   2025-02-28   Internet Banking INTERNET TRANSFER 302543818917   2025
# 7   2025-03-31   Internet Banking INTERNET TRANSFER 838173975039   2025
# 8   2025-03-31  Internet Banking E-TRANSFER 410913019913 LANDLORD  2025
# 9   2025-03-31  Internet Banking E-TRANSFER 528426674492 LANDLORD  2025
# 10  2025-04-30  Internet Banking E-TRANSFER 829120631610 LANDLORD  2025
# 11  2025-04-30  Internet Banking E-TRANSFER 200541329033 LANDLORD  2025
# 12  2025-04-30   Internet Banking INTERNET TRANSFER 732015329788   2025
# 13  2025-05-31  Internet Banking E-TRANSFER 625353525455 LANDLORD  2025
# 14  2025-05-31  Internet Banking E-TRANSFER 513036925420 LANDLORD  2025
# 15  2025-05-31   Internet Banking INTERNET TRANSFER 199266785895   2025
# 16  2025-06-30  Internet Banking E-TRANSFER 966334448033 LANDLORD  2025
# 17  2025-06-30   Internet Banking INTERNET TRANSFER 647328542519   2025
# 18  2025-06-30  Internet Banking E-TRANSFER 546538355224 LANDLORD  2025
# 19  2025-07-31  Internet Banking E-TRANSFER 875882121947 LANDLORD  2025
# 20  2025-07-31  Internet Banking E-TRANSFER 130782139534 LANDLORD  2025
# 21  2025-07-31   Internet Banking INTERNET TRANSFER 224938125884   2025
# 22  2025-08-31  Internet Banking E-TRANSFER 252841963626 LANDLORD  2025
# 23  2025-08-31  Internet Banking E-TRANSFER 773497235500 LANDLORD  2025
# 24  2025-08-31   Internet Banking INTERNET TRANSFER 213841671997   2025
# 25  2025-09-30   Internet Banking INTERNET TRANSFER 055336254384   2025
# 26  2025-09-30  Internet Banking E-TRANSFER 515191359104 LANDLORD  2025
# 27  2025-09-30  Internet Banking E-TRANSFER 089744038644 LANDLORD  2025
# 28  2025-10-31  Internet Banking E-TRANSFER 176098198763 LANDLORD  2025
# 29  2025-10-31  Internet Banking E-TRANSFER 166437367261 LANDLORD  2025
# 30  2025-10-31   Internet Banking INTERNET TRANSFER 576395623352   2025
# 31  2025-11-30  Internet Banking E-TRANSFER 642949362465 LANDLORD  2025
# 32  2025-11-30  Internet Banking E-TRANSFER 595706408477 LANDLORD  2025
# 33  2025-11-30   Internet Banking INTERNET TRANSFER 217777030307   2025
# 34  2025-12-31  Internet Banking E-TRANSFER 103978351491 LANDLORD  2025
# 35  2025-12-31  Internet Banking E-TRANSFER 181227351012 LANDLORD  2025
# 36  2025-12-31   Internet Banking INTERNET TRANSFER 794179128749   2025
#
#     month  day  account   amount                     method  \
# 0       1    1  savings   2000.0  automated banking machine
# 1       1   31  savings  -1500.0           internet banking
# 2       1   31  savings   -283.0           internet banking
# 3       1   31  savings  50000.0           internet banking
# 4       2   28  savings  -1500.0           internet banking
# 5       2   28  savings   -277.0           internet banking
# 6       2   28  savings  50000.0           internet banking
# 7       3   31  savings  50000.0           internet banking
# 8       3   31  savings   -284.0           internet banking
# 9       3   31  savings  -1500.0           internet banking
# 10      4   30  savings  -1500.0           internet banking
# 11      4   30  savings   -291.0           internet banking
# 12      4   30  savings  50000.0           internet banking
# 13      5   31  savings  -1500.0           internet banking
# 14      5   31  savings   -294.0           internet banking
# 15      5   31  savings  50000.0           internet banking
# 16      6   30  savings   -264.0           internet banking
# 17      6   30  savings  50000.0           internet banking
# 18      6   30  savings  -1500.0           internet banking
# 19      7   31  savings  -1500.0           internet banking
# 20      7   31  savings   -268.0           internet banking
# 21      7   31  savings  50000.0           internet banking
# 22      8   31  savings  -1500.0           internet banking
# 23      8   31  savings   -253.0           internet banking
# 24      8   31  savings  50000.0           internet banking
# 25      9   30  savings  50000.0           internet banking
# 26      9   30  savings  -1500.0           internet banking
# 27      9   30  savings   -261.0           internet banking
# 28     10   31  savings  -1500.0           internet banking
# 29     10   31  savings   -277.0           internet banking
# 30     10   31  savings  50000.0           internet banking
# 31     11   30  savings  -1500.0           internet banking
# 32     11   30  savings   -286.0           internet banking
# 33     11   30  savings  50000.0           internet banking
# 34     12   31  savings   -279.0           internet banking
# 35     12   31  savings  -1500.0           internet banking
# 36     12   31  savings  50000.0           internet banking
#
#                  type     party  index_copy  uid
# 0         atm deposit       NaN           0    1
# 1          e-transfer  landlord           1   46
# 2          e-transfer  landlord           2   45
# 3   internet transfer       NaN           3   51
# 4          e-transfer  landlord           4   93
# 5          e-transfer  landlord           5   94
# 6   internet transfer       NaN           6   96
# 7   internet transfer       NaN           7  145
# 8          e-transfer  landlord           8  143
# 9          e-transfer  landlord           9  144
# 10         e-transfer  landlord          10  196
# 11         e-transfer  landlord          11  197
# 12  internet transfer       NaN          12  192
# 13         e-transfer  landlord          13  242
# 14         e-transfer  landlord          14  240
# 15  internet transfer       NaN          15  241
# 16         e-transfer  landlord          16  293
# 17  internet transfer       NaN          17  292
# 18         e-transfer  landlord          18  291
# 19         e-transfer  landlord          19  345
# 20         e-transfer  landlord          20  346
# 21  internet transfer       NaN          21  347
# 22         e-transfer  landlord          22  393
# 23         e-transfer  landlord          23  394
# 24  internet transfer       NaN          24  395
# 25  internet transfer       NaN          25  443
# 26         e-transfer  landlord          26  444
# 27         e-transfer  landlord          27  445
# 28         e-transfer  landlord          28  493
# 29         e-transfer  landlord          29  494
# 30  internet transfer       NaN          30  490
# 31         e-transfer  landlord          31  544
# 32         e-transfer  landlord          32  539
# 33  internet transfer       NaN          33  543
# 34         e-transfer  landlord          34  554
# 35         e-transfer  landlord          35  553
# 36  internet transfer       NaN          36  552

# %%
expanded_chequing_df = expanded_chequing_df.sort_index()
expanded_chequing_df["uid"] = combined_expanded_df.loc[combined_expanded_df["account"] == "chequing"].sort_index()["uid"]
expanded_chequing_df
# Out:
#            date                                        description  year  \
# 0    2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 1    2025-01-01  Internet Banking E-TRANSFER 198387442408 BLUE ...  2025
# 2    2025-01-02  Point of Sale - Interac RETAIL PURCHASE 739855...  2025
# 3    2025-01-02  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# 4    2025-01-03  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# ..          ...                                                ...   ...
# 416  2025-12-01  Internet Banking E-TRANSFER 510912177359 BLUE ...  2025
# 417  2025-12-02   Internet Banking INTERNET TRANSFER 872872991979   2025
# 418  2025-12-02  Point of Sale - Interac RETAIL PURCHASE 925576...  2025
# 419  2025-12-31   Internet Banking INTERNET TRANSFER 794179128749   2025
# 420  2025-12-31                    Branch Transaction CREDIT MEMO   2025
#
#      month  day   account   amount                      method  \
# 0        1    1  chequing   2000.0   automated banking machine
# 1        1    1  chequing    -50.0            internet banking
# 2        1    2  chequing    -16.0     point of sale - interac
# 3        1    2  chequing     -3.0  point of sale - visa debit
# 4        1    3  chequing    -10.0  point of sale - visa debit
# ..     ...  ...       ...      ...                         ...
# 416     12    1  chequing    -50.0            internet banking
# 417     12    2  chequing    -54.0            internet banking
# 418     12    2  chequing    -16.0     point of sale - interac
# 419     12   31  chequing -50000.0            internet banking
# 420     12   31  chequing   7000.0          branch transaction
#
#                            type             party  index_copy  uid
# 0                   atm deposit               NaN           0    3
# 1                    e-transfer  blue hockey club           1    2
# 2               retail purchase             pizza           2    5
# 3    visa debit retail purchase            presto           3    4
# 4    visa debit retail purchase            presto           4    6
# ..                          ...               ...         ...  ...
# 416                  e-transfer  blue hockey club         416  545
# 417           internet transfer               NaN         417  546
# 418             retail purchase             pizza         418  547
# 419           internet transfer               NaN         419  550
# 420                 credit memo               NaN         420  551
#
# [421 rows x 12 columns]

# %%
expanded_credit_df = expanded_credit_df.sort_index()
expanded_credit_df["uid"] = combined_expanded_df.loc[combined_expanded_df["account"] == "credit"].sort_index()["uid"]
expanded_credit_df
# Out:
#           date                        description  year  month  day account  \
# 0   2025-01-07                WALMART TORONTO, ON  2025      1    7  credit
# 1   2025-01-07  PAYMENT THANK YOU/PAIEMEN T MERCI  2025      1    7  credit
# 2   2025-01-14                WALMART TORONTO, ON  2025      1   14  credit
# 3   2025-01-14  PAYMENT THANK YOU/PAIEMEN T MERCI  2025      1   14  credit
# 4   2025-01-21                WALMART TORONTO, ON  2025      1   21  credit
# ..         ...                                ...   ...    ...  ...     ...
# 91  2025-11-18  PAYMENT THANK YOU/PAIEMEN T MERCI  2025     11   18  credit
# 92  2025-11-25                WALMART TORONTO, ON  2025     11   25  credit
# 93  2025-11-25  PAYMENT THANK YOU/PAIEMEN T MERCI  2025     11   25  credit
# 94  2025-12-02                WALMART TORONTO, ON  2025     12    2  credit
# 95  2025-12-02  PAYMENT THANK YOU/PAIEMEN T MERCI  2025     12    2  credit
#
#     amount    party  uid
# 0    -78.0  walmart   13
# 1     78.0      NaN   10
# 2    -65.0  walmart   23
# 3     65.0      NaN   22
# 4    -92.0  walmart   32
# ..     ...      ...  ...
# 91    60.0      NaN  520
# 92   -83.0  walmart  532
# 93    83.0      NaN  533
# 94   -54.0  walmart  548
# 95    54.0      NaN  549
#
# [96 rows x 9 columns]

# %%
merged_df = expanded_savings_df.merge(expanded_chequing_df, left_on="description", right_on="description")
merged_df = merged_df.loc[merged_df["amount_x"] == -1 * merged_df["amount_y"]]
merged_df
# Out:
#         date_x                                       description  year_x  \
# 1   2025-01-31  Internet Banking INTERNET TRANSFER 125959237893     2025
# 2   2025-02-28  Internet Banking INTERNET TRANSFER 302543818917     2025
# 3   2025-03-31  Internet Banking INTERNET TRANSFER 838173975039     2025
# 4   2025-04-30  Internet Banking INTERNET TRANSFER 732015329788     2025
# 5   2025-05-31  Internet Banking INTERNET TRANSFER 199266785895     2025
# 6   2025-06-30  Internet Banking INTERNET TRANSFER 647328542519     2025
# 7   2025-07-31  Internet Banking INTERNET TRANSFER 224938125884     2025
# 8   2025-08-31  Internet Banking INTERNET TRANSFER 213841671997     2025
# 9   2025-09-30  Internet Banking INTERNET TRANSFER 055336254384     2025
# 10  2025-10-31  Internet Banking INTERNET TRANSFER 576395623352     2025
# 11  2025-11-30  Internet Banking INTERNET TRANSFER 217777030307     2025
# 12  2025-12-31  Internet Banking INTERNET TRANSFER 794179128749     2025
#
#     month_x  day_x account_x  amount_x          method_x             type_x  \
# 1         1     31   savings   50000.0  internet banking  internet transfer
# 2         2     28   savings   50000.0  internet banking  internet transfer
# 3         3     31   savings   50000.0  internet banking  internet transfer
# 4         4     30   savings   50000.0  internet banking  internet transfer
# 5         5     31   savings   50000.0  internet banking  internet transfer
# 6         6     30   savings   50000.0  internet banking  internet transfer
# 7         7     31   savings   50000.0  internet banking  internet transfer
# 8         8     31   savings   50000.0  internet banking  internet transfer
# 9         9     30   savings   50000.0  internet banking  internet transfer
# 10       10     31   savings   50000.0  internet banking  internet transfer
# 11       11     30   savings   50000.0  internet banking  internet transfer
# 12       12     31   savings   50000.0  internet banking  internet transfer
#
#    party_x  ...  year_y  month_y day_y  account_y  amount_y          method_y  \
# 1      NaN  ...    2025        1    31   chequing  -50000.0  internet banking
# 2      NaN  ...    2025        2    28   chequing  -50000.0  internet banking
# 3      NaN  ...    2025        3    31   chequing  -50000.0  internet banking
# 4      NaN  ...    2025        4    30   chequing  -50000.0  internet banking
# 5      NaN  ...    2025        5    31   chequing  -50000.0  internet banking
# 6      NaN  ...    2025        6    30   chequing  -50000.0  internet banking
# 7      NaN  ...    2025        7    31   chequing  -50000.0  internet banking
# 8      NaN  ...    2025        8    31   chequing  -50000.0  internet banking
# 9      NaN  ...    2025        9    30   chequing  -50000.0  internet banking
# 10     NaN  ...    2025       10    31   chequing  -50000.0  internet banking
# 11     NaN  ...    2025       11    30   chequing  -50000.0  internet banking
# 12     NaN  ...    2025       12    31   chequing  -50000.0  internet banking
#
#                type_y  party_y index_copy_y uid_y
# 1   internet transfer      NaN           38    50
# 2   internet transfer      NaN           72    95
# 3   internet transfer      NaN          110   142
# 4   internet transfer      NaN          147   195
# 5   internet transfer      NaN          184   243
# 6   internet transfer      NaN          221   287
# 7   internet transfer      NaN          261   343
# 8   internet transfer      NaN          301   392
# 9   internet transfer      NaN          337   439
# 10  internet transfer      NaN          376   492
# 11  internet transfer      NaN          414   541
# 12  internet transfer      NaN          419   550
#
# [12 rows x 23 columns]

# %%
internal_transfer_df = pd.concat([
    expanded_savings_df.loc[merged_df["index_copy_x"]],
    expanded_chequing_df.loc[merged_df["index_copy_y"]]
]).drop(columns=["index_copy", "party"]).sort_values(by=["uid"]).reset_index(drop=True)
internal_transfer_df
# Out:
#           date                                       description  year  month  \
# 0   2025-01-31  Internet Banking INTERNET TRANSFER 125959237893   2025      1
# 1   2025-01-31  Internet Banking INTERNET TRANSFER 125959237893   2025      1
# 2   2025-02-28  Internet Banking INTERNET TRANSFER 302543818917   2025      2
# 3   2025-02-28  Internet Banking INTERNET TRANSFER 302543818917   2025      2
# 4   2025-03-31  Internet Banking INTERNET TRANSFER 838173975039   2025      3
# 5   2025-03-31  Internet Banking INTERNET TRANSFER 838173975039   2025      3
# 6   2025-04-30  Internet Banking INTERNET TRANSFER 732015329788   2025      4
# 7   2025-04-30  Internet Banking INTERNET TRANSFER 732015329788   2025      4
# 8   2025-05-31  Internet Banking INTERNET TRANSFER 199266785895   2025      5
# 9   2025-05-31  Internet Banking INTERNET TRANSFER 199266785895   2025      5
# 10  2025-06-30  Internet Banking INTERNET TRANSFER 647328542519   2025      6
# 11  2025-06-30  Internet Banking INTERNET TRANSFER 647328542519   2025      6
# 12  2025-07-31  Internet Banking INTERNET TRANSFER 224938125884   2025      7
# 13  2025-07-31  Internet Banking INTERNET TRANSFER 224938125884   2025      7
# 14  2025-08-31  Internet Banking INTERNET TRANSFER 213841671997   2025      8
# 15  2025-08-31  Internet Banking INTERNET TRANSFER 213841671997   2025      8
# 16  2025-09-30  Internet Banking INTERNET TRANSFER 055336254384   2025      9
# 17  2025-09-30  Internet Banking INTERNET TRANSFER 055336254384   2025      9
# 18  2025-10-31  Internet Banking INTERNET TRANSFER 576395623352   2025     10
# 19  2025-10-31  Internet Banking INTERNET TRANSFER 576395623352   2025     10
# 20  2025-11-30  Internet Banking INTERNET TRANSFER 217777030307   2025     11
# 21  2025-11-30  Internet Banking INTERNET TRANSFER 217777030307   2025     11
# 22  2025-12-31  Internet Banking INTERNET TRANSFER 794179128749   2025     12
# 23  2025-12-31  Internet Banking INTERNET TRANSFER 794179128749   2025     12
#
#     day   account   amount            method               type  uid
# 0    31  chequing -50000.0  internet banking  internet transfer   50
# 1    31   savings  50000.0  internet banking  internet transfer   51
# 2    28  chequing -50000.0  internet banking  internet transfer   95
# 3    28   savings  50000.0  internet banking  internet transfer   96
# 4    31  chequing -50000.0  internet banking  internet transfer  142
# 5    31   savings  50000.0  internet banking  internet transfer  145
# 6    30   savings  50000.0  internet banking  internet transfer  192
# 7    30  chequing -50000.0  internet banking  internet transfer  195
# 8    31   savings  50000.0  internet banking  internet transfer  241
# 9    31  chequing -50000.0  internet banking  internet transfer  243
# 10   30  chequing -50000.0  internet banking  internet transfer  287
# 11   30   savings  50000.0  internet banking  internet transfer  292
# 12   31  chequing -50000.0  internet banking  internet transfer  343
# 13   31   savings  50000.0  internet banking  internet transfer  347
# 14   31  chequing -50000.0  internet banking  internet transfer  392
# 15   31   savings  50000.0  internet banking  internet transfer  395
# 16   30  chequing -50000.0  internet banking  internet transfer  439
# 17   30   savings  50000.0  internet banking  internet transfer  443
# 18   31   savings  50000.0  internet banking  internet transfer  490
# 19   31  chequing -50000.0  internet banking  internet transfer  492
# 20   30  chequing -50000.0  internet banking  internet transfer  541
# 21   30   savings  50000.0  internet banking  internet transfer  543
# 22   31  chequing -50000.0  internet banking  internet transfer  550
# 23   31   savings  50000.0  internet banking  internet transfer  552

# %%
raw_debit_df = pd.concat([
    expanded_savings_df.drop(merged_df["index_copy_x"]),
    expanded_chequing_df.drop(merged_df["index_copy_y"])
]).drop(columns=["index_copy"]).reset_index(drop=True)
raw_debit_df
# Out:
#            date                                        description  year  \
# 0    2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 1    2025-01-31  Internet Banking E-TRANSFER 497466188861 LANDLORD  2025
# 2    2025-01-31  Internet Banking E-TRANSFER 023468170802 LANDLORD  2025
# 3    2025-02-28  Internet Banking E-TRANSFER 233755062894 LANDLORD  2025
# 4    2025-02-28  Internet Banking E-TRANSFER 307059499977 LANDLORD  2025
# ..          ...                                                ...   ...
# 429  2025-11-30  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# 430  2025-12-01  Internet Banking E-TRANSFER 510912177359 BLUE ...  2025
# 431  2025-12-02   Internet Banking INTERNET TRANSFER 872872991979   2025
# 432  2025-12-02  Point of Sale - Interac RETAIL PURCHASE 925576...  2025
# 433  2025-12-31                    Branch Transaction CREDIT MEMO   2025
#
#      month  day   account  amount                      method  \
# 0        1    1   savings  2000.0   automated banking machine
# 1        1   31   savings -1500.0            internet banking
# 2        1   31   savings  -283.0            internet banking
# 3        2   28   savings -1500.0            internet banking
# 4        2   28   savings  -277.0            internet banking
# ..     ...  ...       ...     ...                         ...
# 429     11   30  chequing    -3.0  point of sale - visa debit
# 430     12    1  chequing   -50.0            internet banking
# 431     12    2  chequing   -54.0            internet banking
# 432     12    2  chequing   -16.0     point of sale - interac
# 433     12   31  chequing  7000.0          branch transaction
#
#                            type             party  uid
# 0                   atm deposit               NaN    1
# 1                    e-transfer          landlord   46
# 2                    e-transfer          landlord   45
# 3                    e-transfer          landlord   93
# 4                    e-transfer          landlord   94
# ..                          ...               ...  ...
# 429  visa debit retail purchase            presto  542
# 430                  e-transfer  blue hockey club  545
# 431           internet transfer               NaN  546
# 432             retail purchase             pizza  547
# 433                 credit memo               NaN  551
#
# [434 rows x 11 columns]

# %%
internal_payment_from_debit_df = raw_debit_df.loc[
    (raw_debit_df["method"] == "internet banking") &
    (raw_debit_df["type"] == "internet transfer")
].drop(columns=["party"])
internal_payment_from_debit_df
# Out:
#            date                                       description  year  \
# 33   2025-01-07  Internet Banking INTERNET TRANSFER 116494411368   2025
# 41   2025-01-14  Internet Banking INTERNET TRANSFER 493121374759   2025
# 50   2025-01-21  Internet Banking INTERNET TRANSFER 040555104405   2025
# 58   2025-01-28  Internet Banking INTERNET TRANSFER 869401334317   2025
# 68   2025-02-04  Internet Banking INTERNET TRANSFER 286836600491   2025
# 75   2025-02-11  Internet Banking INTERNET TRANSFER 039959504015   2025
# 83   2025-02-18  Internet Banking INTERNET TRANSFER 379970909730   2025
# 91   2025-02-25  Internet Banking INTERNET TRANSFER 607465394041   2025
# 101  2025-03-04  Internet Banking INTERNET TRANSFER 681876139712   2025
# 110  2025-03-11  Internet Banking INTERNET TRANSFER 607294766562   2025
# 118  2025-03-18  Internet Banking INTERNET TRANSFER 047413825653   2025
# 126  2025-03-25  Internet Banking INTERNET TRANSFER 382340457884   2025
# 136  2025-04-01  Internet Banking INTERNET TRANSFER 526734280228   2025
# 144  2025-04-08  Internet Banking INTERNET TRANSFER 297717932403   2025
# 151  2025-04-15  Internet Banking INTERNET TRANSFER 848361824195   2025
# 160  2025-04-22  Internet Banking INTERNET TRANSFER 629172007785   2025
# 167  2025-04-29  Internet Banking INTERNET TRANSFER 128870042687   2025
# 178  2025-05-06  Internet Banking INTERNET TRANSFER 599074908156   2025
# 185  2025-05-13  Internet Banking INTERNET TRANSFER 897768053229   2025
# 194  2025-05-20  Internet Banking INTERNET TRANSFER 834782369574   2025
# 202  2025-05-27  Internet Banking INTERNET TRANSFER 940480620883   2025
# 211  2025-06-03  Internet Banking INTERNET TRANSFER 894178696901   2025
# 219  2025-06-10  Internet Banking INTERNET TRANSFER 009178056669   2025
# 227  2025-06-17  Internet Banking INTERNET TRANSFER 158981685943   2025
# 236  2025-06-24  Internet Banking INTERNET TRANSFER 016569579908   2025
# 244  2025-07-01  Internet Banking INTERNET TRANSFER 142194351328   2025
# 254  2025-07-08  Internet Banking INTERNET TRANSFER 221314724387   2025
# 262  2025-07-15  Internet Banking INTERNET TRANSFER 594183640946   2025
# 270  2025-07-22  Internet Banking INTERNET TRANSFER 405218073426   2025
# 276  2025-07-29  Internet Banking INTERNET TRANSFER 107953442586   2025
# 286  2025-08-05  Internet Banking INTERNET TRANSFER 193612050306   2025
# 296  2025-08-12  Internet Banking INTERNET TRANSFER 909054558438   2025
# 304  2025-08-19  Internet Banking INTERNET TRANSFER 331099586341   2025
# 312  2025-08-26  Internet Banking INTERNET TRANSFER 733556323641   2025
# 322  2025-09-02  Internet Banking INTERNET TRANSFER 828066760887   2025
# 330  2025-09-09  Internet Banking INTERNET TRANSFER 261960991451   2025
# 338  2025-09-16  Internet Banking INTERNET TRANSFER 290554455395   2025
# 346  2025-09-23  Internet Banking INTERNET TRANSFER 087024874084   2025
# 354  2025-09-30  Internet Banking INTERNET TRANSFER 918839624138   2025
# 364  2025-10-07  Internet Banking INTERNET TRANSFER 802626685620   2025
# 372  2025-10-14  Internet Banking INTERNET TRANSFER 996511242069   2025
# 380  2025-10-21  Internet Banking INTERNET TRANSFER 481690522947   2025
# 388  2025-10-28  Internet Banking INTERNET TRANSFER 068339714724   2025
# 398  2025-11-04  Internet Banking INTERNET TRANSFER 856585689624   2025
# 406  2025-11-11  Internet Banking INTERNET TRANSFER 981311396885   2025
# 413  2025-11-18  Internet Banking INTERNET TRANSFER 795273423770   2025
# 422  2025-11-25  Internet Banking INTERNET TRANSFER 803749812307   2025
# 431  2025-12-02  Internet Banking INTERNET TRANSFER 872872991979   2025
#
#      month  day   account  amount            method               type  uid
# 33       1    7  chequing   -78.0  internet banking  internet transfer   12
# 41       1   14  chequing   -65.0  internet banking  internet transfer   21
# 50       1   21  chequing   -92.0  internet banking  internet transfer   30
# 58       1   28  chequing   -75.0  internet banking  internet transfer   41
# 68       2    4  chequing   -86.0  internet banking  internet transfer   59
# 75       2   11  chequing   -86.0  internet banking  internet transfer   67
# 83       2   18  chequing   -82.0  internet banking  internet transfer   79
# 91       2   25  chequing   -94.0  internet banking  internet transfer   88
# 101      3    4  chequing   -55.0  internet banking  internet transfer  104
# 110      3   11  chequing   -56.0  internet banking  internet transfer  113
# 118      3   18  chequing   -58.0  internet banking  internet transfer  122
# 126      3   25  chequing   -88.0  internet banking  internet transfer  134
# 136      4    1  chequing   -97.0  internet banking  internet transfer  146
# 144      4    8  chequing   -80.0  internet banking  internet transfer  160
# 151      4   15  chequing   -87.0  internet banking  internet transfer  168
# 160      4   22  chequing   -52.0  internet banking  internet transfer  180
# 167      4   29  chequing   -53.0  internet banking  internet transfer  190
# 178      5    6  chequing   -72.0  internet banking  internet transfer  206
# 185      5   13  chequing   -59.0  internet banking  internet transfer  214
# 194      5   20  chequing   -97.0  internet banking  internet transfer  225
# 202      5   27  chequing   -68.0  internet banking  internet transfer  237
# 211      6    3  chequing   -56.0  internet banking  internet transfer  251
# 219      6   10  chequing   -61.0  internet banking  internet transfer  260
# 227      6   17  chequing   -88.0  internet banking  internet transfer  270
# 236      6   24  chequing   -52.0  internet banking  internet transfer  283
# 244      7    1  chequing   -75.0  internet banking  internet transfer  294
# 254      7    8  chequing   -73.0  internet banking  internet transfer  309
# 262      7   15  chequing   -86.0  internet banking  internet transfer  319
# 270      7   22  chequing   -57.0  internet banking  internet transfer  327
# 276      7   29  chequing   -71.0  internet banking  internet transfer  337
# 286      8    5  chequing   -51.0  internet banking  internet transfer  352
# 296      8   12  chequing   -92.0  internet banking  internet transfer  365
# 304      8   19  chequing   -71.0  internet banking  internet transfer  375
# 312      8   26  chequing   -55.0  internet banking  internet transfer  383
# 322      9    2  chequing   -68.0  internet banking  internet transfer  400
# 330      9    9  chequing   -85.0  internet banking  internet transfer  411
# 338      9   16  chequing   -76.0  internet banking  internet transfer  420
# 346      9   23  chequing   -54.0  internet banking  internet transfer  431
# 354      9   30  chequing   -84.0  internet banking  internet transfer  440
# 364     10    7  chequing   -94.0  internet banking  internet transfer  455
# 372     10   14  chequing   -93.0  internet banking  internet transfer  466
# 380     10   21  chequing   -58.0  internet banking  internet transfer  477
# 388     10   28  chequing   -99.0  internet banking  internet transfer  486
# 398     11    4  chequing   -79.0  internet banking  internet transfer  502
# 406     11   11  chequing   -56.0  internet banking  internet transfer  513
# 413     11   18  chequing   -60.0  internet banking  internet transfer  522
# 422     11   25  chequing   -83.0  internet banking  internet transfer  531
# 431     12    2  chequing   -54.0  internet banking  internet transfer  546

# %%
credit_payment_bool_series = expanded_credit_df["description"].str.contains("PAYMENT THANK YOU")

# %%
internal_payment_df = pd.concat([
    internal_payment_from_debit_df,
    expanded_credit_df.loc[credit_payment_bool_series]
]).drop(columns=["party"]).sort_values(by=["uid"]).reset_index(drop=True)
internal_payment_df
# Out:
#           date                                       description  year  month  \
# 0   2025-01-07                 PAYMENT THANK YOU/PAIEMEN T MERCI  2025      1
# 1   2025-01-07  Internet Banking INTERNET TRANSFER 116494411368   2025      1
# 2   2025-01-14  Internet Banking INTERNET TRANSFER 493121374759   2025      1
# 3   2025-01-14                 PAYMENT THANK YOU/PAIEMEN T MERCI  2025      1
# 4   2025-01-21  Internet Banking INTERNET TRANSFER 040555104405   2025      1
# ..         ...                                               ...   ...    ...
# 91  2025-11-18  Internet Banking INTERNET TRANSFER 795273423770   2025     11
# 92  2025-11-25  Internet Banking INTERNET TRANSFER 803749812307   2025     11
# 93  2025-11-25                 PAYMENT THANK YOU/PAIEMEN T MERCI  2025     11
# 94  2025-12-02  Internet Banking INTERNET TRANSFER 872872991979   2025     12
# 95  2025-12-02                 PAYMENT THANK YOU/PAIEMEN T MERCI  2025     12
#
#     day   account  amount            method               type  uid
# 0     7    credit    78.0               NaN                NaN   10
# 1     7  chequing   -78.0  internet banking  internet transfer   12
# 2    14  chequing   -65.0  internet banking  internet transfer   21
# 3    14    credit    65.0               NaN                NaN   22
# 4    21  chequing   -92.0  internet banking  internet transfer   30
# ..  ...       ...     ...               ...                ...  ...
# 91   18  chequing   -60.0  internet banking  internet transfer  522
# 92   25  chequing   -83.0  internet banking  internet transfer  531
# 93   25    credit    83.0               NaN                NaN  533
# 94    2  chequing   -54.0  internet banking  internet transfer  546
# 95    2    credit    54.0               NaN                NaN  549
#
# [96 rows x 10 columns]

# %%
debit_df = raw_debit_df.drop(internal_payment_from_debit_df.index).reset_index(drop=True)
debit_df
# Out:
#            date                                        description  year  \
# 0    2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 1    2025-01-31  Internet Banking E-TRANSFER 497466188861 LANDLORD  2025
# 2    2025-01-31  Internet Banking E-TRANSFER 023468170802 LANDLORD  2025
# 3    2025-02-28  Internet Banking E-TRANSFER 233755062894 LANDLORD  2025
# 4    2025-02-28  Internet Banking E-TRANSFER 307059499977 LANDLORD  2025
# ..          ...                                                ...   ...
# 381  2025-11-30                    Branch Transaction CREDIT MEMO   2025
# 382  2025-11-30  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# 383  2025-12-01  Internet Banking E-TRANSFER 510912177359 BLUE ...  2025
# 384  2025-12-02  Point of Sale - Interac RETAIL PURCHASE 925576...  2025
# 385  2025-12-31                    Branch Transaction CREDIT MEMO   2025
#
#      month  day   account  amount                      method  \
# 0        1    1   savings  2000.0   automated banking machine
# 1        1   31   savings -1500.0            internet banking
# 2        1   31   savings  -283.0            internet banking
# 3        2   28   savings -1500.0            internet banking
# 4        2   28   savings  -277.0            internet banking
# ..     ...  ...       ...     ...                         ...
# 381     11   30  chequing  7000.0          branch transaction
# 382     11   30  chequing    -3.0  point of sale - visa debit
# 383     12    1  chequing   -50.0            internet banking
# 384     12    2  chequing   -16.0     point of sale - interac
# 385     12   31  chequing  7000.0          branch transaction
#
#                            type             party  uid
# 0                   atm deposit               NaN    1
# 1                    e-transfer          landlord   46
# 2                    e-transfer          landlord   45
# 3                    e-transfer          landlord   93
# 4                    e-transfer          landlord   94
# ..                          ...               ...  ...
# 381                 credit memo               NaN  540
# 382  visa debit retail purchase            presto  542
# 383                  e-transfer  blue hockey club  545
# 384             retail purchase             pizza  547
# 385                 credit memo               NaN  551
#
# [386 rows x 11 columns]

# %%
def get_sign(amount):
    if amount > 0:
        return "income"
    elif amount < 0:
        return "expense"
    return "zero-value"

# %%
cash_flow_df = pd.concat([
    debit_df,
    expanded_credit_df.loc[~credit_payment_bool_series]
]).sort_values(by=["uid"]).reset_index(drop=True)
cash_flow_df["sign"] = cash_flow_df["amount"].apply(get_sign)
cash_flow_df
# Out:
#            date                                        description  year  \
# 0    2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 1    2025-01-01  Internet Banking E-TRANSFER 198387442408 BLUE ...  2025
# 2    2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 3    2025-01-02  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# 4    2025-01-02  Point of Sale - Interac RETAIL PURCHASE 739855...  2025
# ..          ...                                                ...   ...
# 429  2025-12-02  Point of Sale - Interac RETAIL PURCHASE 925576...  2025
# 430  2025-12-02                                WALMART TORONTO, ON  2025
# 431  2025-12-31                    Branch Transaction CREDIT MEMO   2025
# 432  2025-12-31  Internet Banking E-TRANSFER 181227351012 LANDLORD  2025
# 433  2025-12-31  Internet Banking E-TRANSFER 103978351491 LANDLORD  2025
#
#      month  day   account  amount                      method  \
# 0        1    1   savings  2000.0   automated banking machine
# 1        1    1  chequing   -50.0            internet banking
# 2        1    1  chequing  2000.0   automated banking machine
# 3        1    2  chequing    -3.0  point of sale - visa debit
# 4        1    2  chequing   -16.0     point of sale - interac
# ..     ...  ...       ...     ...                         ...
# 429     12    2  chequing   -16.0     point of sale - interac
# 430     12    2    credit   -54.0                         NaN
# 431     12   31  chequing  7000.0          branch transaction
# 432     12   31   savings -1500.0            internet banking
# 433     12   31   savings  -279.0            internet banking
#
#                            type             party  uid     sign
# 0                   atm deposit               NaN    1   income
# 1                    e-transfer  blue hockey club    2  expense
# 2                   atm deposit               NaN    3   income
# 3    visa debit retail purchase            presto    4  expense
# 4               retail purchase             pizza    5  expense
# ..                          ...               ...  ...      ...
# 429             retail purchase             pizza  547  expense
# 430                         NaN           walmart  548  expense
# 431                 credit memo               NaN  551   income
# 432                  e-transfer          landlord  553  expense
# 433                  e-transfer          landlord  554  expense
#
# [434 rows x 12 columns]

# %%
with pd.ExcelWriter('output.xlsx') as writer:
    cash_flow_df.to_excel(writer, sheet_name="cash_flow", index=False)
    internal_transfer_df.to_excel(writer, sheet_name="internal_transfer", index=False)
    internal_payment_df.to_excel(writer, sheet_name="internal_payment", index=False)

# %% [markdown]
# ## Command Test

# %%
# db_df = pd.read_excel("C:/Users/Daniel/Documents/Git/bank-statement-cleaner/outdated.xlsx", sheet_name=None)
# db_df

# %%
# internal_payment_df.loc[~internal_payment_df["uid"].isin(db_df["internal_payment"]["uid"])]
