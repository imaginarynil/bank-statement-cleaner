# %% [markdown]
# ## Create

# %%
import re
import pandas as pd
import numpy as np
import os
import string

# %%
dir_path = "C:/Users/Daniel/Documents/Git/bank-statement-cleaner/synthetic_data"

# %%
savings_csv_path = os.path.join(dir_path, "savings.csv")
chequing_csv_path = os.path.join(dir_path, "chequing.csv")
credit_csv_path = os.path.join(dir_path, "credit.csv")

# %%
class CIBCTransactionDescription:
    def __init__(
        self,
        method="",
        type="",
        party=""
    ):
        self.method = method
        self.type = type
        self.party = party

    def to_pd_series(self):
        # convert to lower case to make queries easier
        attributes = [
            self.method,
            self.type,
            self.party
        ]
        for i in range(0, len(attributes)):
            if not attributes[i]:
                attributes[i] = np.nan
            else:
                attributes[i] = attributes[i].lower()
        return pd.Series(attributes)

# %%
def parse_debit_description(description):
    tx_type_match = re.search(r'[A-Z][^a-z0-9]*[A-Z]', description) # get transaction type
    if not tx_type_match:
        return CIBCTransactionDescription().to_pd_series()
    tx_type = tx_type_match.group()
    tx_method = description[:tx_type_match.span()[0] - 1]
    for word in [
        "CHARGE",
        "CORRECTION",
        "DEPOSIT",
        "FEE",
        "INTEREST",
        "MEMO",
        "PAY",
        "PURCHASE",
        "TRANSFER",
    ]:
        word_start_index = tx_type.rfind(word) # scan from right
        if word_start_index == -1:
            continue
        tx_type = tx_type[:word_start_index + len(word)]
        # special case for service charges
        if word == "CHARGE":
            return CIBCTransactionDescription(
                method=tx_method,
                type=tx_type
            ).to_pd_series()
        break
    tx_type_end_index = tx_type_match.span()[0] + len(tx_type) - 1
    if tx_type_end_index == len(description) - 1:
        return CIBCTransactionDescription(
            method=tx_method,
            type=tx_type
        ).to_pd_series()
    remainder = description[tx_type_end_index + 2:]
    remainder = remainder.replace("*", "") # delete asterisks
    # find a token with only letters and numbers with at least 1 letter and 1 number
    for token in remainder.split(" "):
        if re.search("^[0-9A-Z]+$", token) and re.search("[0-9]", token) and re.search("[A-Z]", token):
            return CIBCTransactionDescription(
                    method=tx_method,
                    type=tx_type,
                    party=remainder.replace(token, "").strip()
                ).to_pd_series()
    # find a token with only numbers
    token_match = re.search("^[0-9]+(?= )|(?<= )[0-9]+$|(?<= )[0-9]+(?= )", remainder)
    if token_match:
        return CIBCTransactionDescription(
            method=tx_method,
            type=tx_type,
            party=remainder.replace(token_match.group(), "").strip()
        ).to_pd_series()
    return CIBCTransactionDescription(
        method=tx_method,
        type=tx_type
    ).to_pd_series()

# %%
def expand_debit(df):
    df[["method", "type", "party"]] = df["description"].apply(parse_debit_description)

# %%
def parse_credit_description(description):
    tx_location_match = re.search(r'[^ ]+, .+$', description) # get transaction location
    if not tx_location_match:
        return np.nan
    return description.replace(tx_location_match.group(), "").strip().lower()

# %%
def expand_credit(df):
    df["party"] = df["description"].apply(parse_credit_description)

# %%
def expand_account_df(account, account_df, expand_fn=None, duplicate_index=True):
    df = account_df.copy()
    date = pd.to_datetime(df["date"])
    df["date"] = date.dt.strftime("%Y-%m-%d")
    df["year"] = date.dt.year
    df["month"] = date.dt.month
    df["day"] = date.dt.day
    df["account"] = account
    df["amount"] = df[["debit", "credit"]].apply(lambda x: x["credit"] if pd.isnull(x["debit"]) else -1 * x["debit"], axis=1)
    df = df.drop(columns=["debit", "credit"])
    if expand_fn:
        expand_fn(df)
    if duplicate_index:
        df["index_copy"] = df.index
    return df

# %%
savings_df = pd.read_csv(savings_csv_path, names=["date", "description", "debit", "credit"])
savings_df
# Out:
#           date                                        description   debit  \
# 0   2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO     NaN
# 1   2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO     NaN
# 2   2025-01-31  Internet Banking E-TRANSFER 891379219227 LANDLORD  1500.0
# 3   2025-01-31  Internet Banking E-TRANSFER 141960766495 LANDLORD   256.0
# 4   2025-01-31   Internet Banking INTERNET TRANSFER 178752671254      NaN
# 5   2025-02-28  Internet Banking E-TRANSFER 899912012729 LANDLORD  1500.0
# 6   2025-02-28  Internet Banking E-TRANSFER 506104578856 LANDLORD   259.0
# 7   2025-02-28   Internet Banking INTERNET TRANSFER 853155311571      NaN
# 8   2025-03-31   Internet Banking INTERNET TRANSFER 193040394515      NaN
# 9   2025-03-31  Internet Banking E-TRANSFER 204002784579 LANDLORD  1500.0
# 10  2025-03-31  Internet Banking E-TRANSFER 601490735807 LANDLORD   271.0
# 11  2025-04-30  Internet Banking E-TRANSFER 375813354092 LANDLORD  1500.0
# 12  2025-04-30  Internet Banking E-TRANSFER 413576083196 LANDLORD   275.0
# 13  2025-04-30   Internet Banking INTERNET TRANSFER 825950711483      NaN
# 14  2025-05-31   Internet Banking INTERNET TRANSFER 354554250700      NaN
# 15  2025-05-31  Internet Banking E-TRANSFER 521834751400 LANDLORD  1500.0
# 16  2025-05-31  Internet Banking E-TRANSFER 701657854702 LANDLORD   282.0
# 17  2025-06-30   Internet Banking INTERNET TRANSFER 617707081506      NaN
# 18  2025-06-30  Internet Banking E-TRANSFER 828826776261 LANDLORD   283.0
# 19  2025-06-30  Internet Banking E-TRANSFER 808388247626 LANDLORD  1500.0
# 20  2025-07-31  Internet Banking E-TRANSFER 221695274493 LANDLORD  1500.0
# 21  2025-07-31  Internet Banking E-TRANSFER 775646115921 LANDLORD   277.0
# 22  2025-07-31   Internet Banking INTERNET TRANSFER 757710935231      NaN
# 23  2025-08-31  Internet Banking E-TRANSFER 919774316604 LANDLORD  1500.0
# 24  2025-08-31  Internet Banking E-TRANSFER 249074173578 LANDLORD   280.0
# 25  2025-08-31   Internet Banking INTERNET TRANSFER 464886862147      NaN
# 26  2025-09-30  Internet Banking E-TRANSFER 277777142749 LANDLORD   254.0
# 27  2025-09-30   Internet Banking INTERNET TRANSFER 786873531098      NaN
# 28  2025-09-30  Internet Banking E-TRANSFER 149029665899 LANDLORD  1500.0
# 29  2025-10-31  Internet Banking E-TRANSFER 722900186038 LANDLORD  1500.0
# 30  2025-10-31  Internet Banking E-TRANSFER 688677006633 LANDLORD   275.0
# 31  2025-10-31   Internet Banking INTERNET TRANSFER 127344273120      NaN
# 32  2025-11-30  Internet Banking E-TRANSFER 383532100904 LANDLORD  1500.0
# 33  2025-11-30  Internet Banking E-TRANSFER 093192064969 LANDLORD   299.0
# 34  2025-11-30   Internet Banking INTERNET TRANSFER 741515855447      NaN
# 35  2025-12-31  Internet Banking E-TRANSFER 149174661918 LANDLORD   255.0
# 36  2025-12-31  Internet Banking E-TRANSFER 483520204193 LANDLORD  1500.0
# 37  2025-12-31   Internet Banking INTERNET TRANSFER 790268759218      NaN
#
#      credit
# 0    2000.0
# 1    2000.0
# 2       NaN
# 3       NaN
# 4   50000.0
# 5       NaN
# 6       NaN
# 7   50000.0
# 8   50000.0
# 9       NaN
# 10      NaN
# 11      NaN
# 12      NaN
# 13  50000.0
# 14  50000.0
# 15      NaN
# 16      NaN
# 17  50000.0
# 18      NaN
# 19      NaN
# 20      NaN
# 21      NaN
# 22  50000.0
# 23      NaN
# 24      NaN
# 25  50000.0
# 26      NaN
# 27  50000.0
# 28      NaN
# 29      NaN
# 30      NaN
# 31  50000.0
# 32      NaN
# 33      NaN
# 34  50000.0
# 35      NaN
# 36      NaN
# 37  50000.0

# %%
expanded_savings_df = expand_account_df("savings", savings_df, expand_fn=expand_debit)
expanded_savings_df
# Out:
#           date                                        description  year  \
# 0   2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 1   2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 2   2025-01-31  Internet Banking E-TRANSFER 891379219227 LANDLORD  2025
# 3   2025-01-31  Internet Banking E-TRANSFER 141960766495 LANDLORD  2025
# 4   2025-01-31   Internet Banking INTERNET TRANSFER 178752671254   2025
# 5   2025-02-28  Internet Banking E-TRANSFER 899912012729 LANDLORD  2025
# 6   2025-02-28  Internet Banking E-TRANSFER 506104578856 LANDLORD  2025
# 7   2025-02-28   Internet Banking INTERNET TRANSFER 853155311571   2025
# 8   2025-03-31   Internet Banking INTERNET TRANSFER 193040394515   2025
# 9   2025-03-31  Internet Banking E-TRANSFER 204002784579 LANDLORD  2025
# 10  2025-03-31  Internet Banking E-TRANSFER 601490735807 LANDLORD  2025
# 11  2025-04-30  Internet Banking E-TRANSFER 375813354092 LANDLORD  2025
# 12  2025-04-30  Internet Banking E-TRANSFER 413576083196 LANDLORD  2025
# 13  2025-04-30   Internet Banking INTERNET TRANSFER 825950711483   2025
# 14  2025-05-31   Internet Banking INTERNET TRANSFER 354554250700   2025
# 15  2025-05-31  Internet Banking E-TRANSFER 521834751400 LANDLORD  2025
# 16  2025-05-31  Internet Banking E-TRANSFER 701657854702 LANDLORD  2025
# 17  2025-06-30   Internet Banking INTERNET TRANSFER 617707081506   2025
# 18  2025-06-30  Internet Banking E-TRANSFER 828826776261 LANDLORD  2025
# 19  2025-06-30  Internet Banking E-TRANSFER 808388247626 LANDLORD  2025
# 20  2025-07-31  Internet Banking E-TRANSFER 221695274493 LANDLORD  2025
# 21  2025-07-31  Internet Banking E-TRANSFER 775646115921 LANDLORD  2025
# 22  2025-07-31   Internet Banking INTERNET TRANSFER 757710935231   2025
# 23  2025-08-31  Internet Banking E-TRANSFER 919774316604 LANDLORD  2025
# 24  2025-08-31  Internet Banking E-TRANSFER 249074173578 LANDLORD  2025
# 25  2025-08-31   Internet Banking INTERNET TRANSFER 464886862147   2025
# 26  2025-09-30  Internet Banking E-TRANSFER 277777142749 LANDLORD  2025
# 27  2025-09-30   Internet Banking INTERNET TRANSFER 786873531098   2025
# 28  2025-09-30  Internet Banking E-TRANSFER 149029665899 LANDLORD  2025
# 29  2025-10-31  Internet Banking E-TRANSFER 722900186038 LANDLORD  2025
# 30  2025-10-31  Internet Banking E-TRANSFER 688677006633 LANDLORD  2025
# 31  2025-10-31   Internet Banking INTERNET TRANSFER 127344273120   2025
# 32  2025-11-30  Internet Banking E-TRANSFER 383532100904 LANDLORD  2025
# 33  2025-11-30  Internet Banking E-TRANSFER 093192064969 LANDLORD  2025
# 34  2025-11-30   Internet Banking INTERNET TRANSFER 741515855447   2025
# 35  2025-12-31  Internet Banking E-TRANSFER 149174661918 LANDLORD  2025
# 36  2025-12-31  Internet Banking E-TRANSFER 483520204193 LANDLORD  2025
# 37  2025-12-31   Internet Banking INTERNET TRANSFER 790268759218   2025
#
#     month  day  account   amount                     method  \
# 0       1    1  savings   2000.0  automated banking machine
# 1       1    1  savings   2000.0  automated banking machine
# 2       1   31  savings  -1500.0           internet banking
# 3       1   31  savings   -256.0           internet banking
# 4       1   31  savings  50000.0           internet banking
# 5       2   28  savings  -1500.0           internet banking
# 6       2   28  savings   -259.0           internet banking
# 7       2   28  savings  50000.0           internet banking
# 8       3   31  savings  50000.0           internet banking
# 9       3   31  savings  -1500.0           internet banking
# 10      3   31  savings   -271.0           internet banking
# 11      4   30  savings  -1500.0           internet banking
# 12      4   30  savings   -275.0           internet banking
# 13      4   30  savings  50000.0           internet banking
# 14      5   31  savings  50000.0           internet banking
# 15      5   31  savings  -1500.0           internet banking
# 16      5   31  savings   -282.0           internet banking
# 17      6   30  savings  50000.0           internet banking
# 18      6   30  savings   -283.0           internet banking
# 19      6   30  savings  -1500.0           internet banking
# 20      7   31  savings  -1500.0           internet banking
# 21      7   31  savings   -277.0           internet banking
# 22      7   31  savings  50000.0           internet banking
# 23      8   31  savings  -1500.0           internet banking
# 24      8   31  savings   -280.0           internet banking
# 25      8   31  savings  50000.0           internet banking
# 26      9   30  savings   -254.0           internet banking
# 27      9   30  savings  50000.0           internet banking
# 28      9   30  savings  -1500.0           internet banking
# 29     10   31  savings  -1500.0           internet banking
# 30     10   31  savings   -275.0           internet banking
# 31     10   31  savings  50000.0           internet banking
# 32     11   30  savings  -1500.0           internet banking
# 33     11   30  savings   -299.0           internet banking
# 34     11   30  savings  50000.0           internet banking
# 35     12   31  savings   -255.0           internet banking
# 36     12   31  savings  -1500.0           internet banking
# 37     12   31  savings  50000.0           internet banking
#
#                  type     party  index_copy
# 0         atm deposit       NaN           0
# 1         atm deposit       NaN           1
# 2          e-transfer  landlord           2
# 3          e-transfer  landlord           3
# 4   internet transfer       NaN           4
# 5          e-transfer  landlord           5
# 6          e-transfer  landlord           6
# 7   internet transfer       NaN           7
# 8   internet transfer       NaN           8
# 9          e-transfer  landlord           9
# 10         e-transfer  landlord          10
# 11         e-transfer  landlord          11
# 12         e-transfer  landlord          12
# 13  internet transfer       NaN          13
# 14  internet transfer       NaN          14
# 15         e-transfer  landlord          15
# 16         e-transfer  landlord          16
# 17  internet transfer       NaN          17
# 18         e-transfer  landlord          18
# 19         e-transfer  landlord          19
# 20         e-transfer  landlord          20
# 21         e-transfer  landlord          21
# 22  internet transfer       NaN          22
# 23         e-transfer  landlord          23
# 24         e-transfer  landlord          24
# 25  internet transfer       NaN          25
# 26         e-transfer  landlord          26
# 27  internet transfer       NaN          27
# 28         e-transfer  landlord          28
# 29         e-transfer  landlord          29
# 30         e-transfer  landlord          30
# 31  internet transfer       NaN          31
# 32         e-transfer  landlord          32
# 33         e-transfer  landlord          33
# 34  internet transfer       NaN          34
# 35         e-transfer  landlord          35
# 36         e-transfer  landlord          36
# 37  internet transfer       NaN          37

# %%
chequing_df = pd.read_csv(chequing_csv_path, names=["date", "description", "debit", "credit"])
chequing_df
# Out:
#            date                                        description    debit  \
# 0    2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO      NaN
# 1    2025-01-01  Internet Banking E-TRANSFER 349282506970 BLUE ...     50.0
# 2    2025-01-02  Point of Sale - Visa Debit VISA DEBIT RETAIL P...      3.0
# 3    2025-01-03  Point of Sale - Visa Debit VISA DEBIT RETAIL P...      9.0
# 4    2025-01-04  Point of Sale - Visa Debit VISA DEBIT RETAIL P...      9.0
# ..          ...                                                ...      ...
# 416  2025-12-01  Point of Sale - Visa Debit VISA DEBIT RETAIL P...      4.0
# 417  2025-12-01  Internet Banking E-TRANSFER 917263704293 BLUE ...     50.0
# 418  2025-12-02   Internet Banking INTERNET TRANSFER 532904682993      93.0
# 419  2025-12-31   Internet Banking INTERNET TRANSFER 790268759218   50000.0
# 420  2025-12-31                    Branch Transaction CREDIT MEMO       NaN
#
#      credit
# 0    2000.0
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ..      ...
# 416     NaN
# 417     NaN
# 418     NaN
# 419     NaN
# 420  7000.0
#
# [421 rows x 4 columns]

# %%
expanded_chequing_df = expand_account_df("chequing", chequing_df, expand_fn=expand_debit)
expanded_chequing_df
# Out:
#            date                                        description  year  \
# 0    2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 1    2025-01-01  Internet Banking E-TRANSFER 349282506970 BLUE ...  2025
# 2    2025-01-02  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# 3    2025-01-03  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# 4    2025-01-04  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# ..          ...                                                ...   ...
# 416  2025-12-01  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# 417  2025-12-01  Internet Banking E-TRANSFER 917263704293 BLUE ...  2025
# 418  2025-12-02   Internet Banking INTERNET TRANSFER 532904682993   2025
# 419  2025-12-31   Internet Banking INTERNET TRANSFER 790268759218   2025
# 420  2025-12-31                    Branch Transaction CREDIT MEMO   2025
#
#      month  day   account   amount                      method  \
# 0        1    1  chequing   2000.0   automated banking machine
# 1        1    1  chequing    -50.0            internet banking
# 2        1    2  chequing     -3.0  point of sale - visa debit
# 3        1    3  chequing     -9.0  point of sale - visa debit
# 4        1    4  chequing     -9.0  point of sale - visa debit
# ..     ...  ...       ...      ...                         ...
# 416     12    1  chequing     -4.0  point of sale - visa debit
# 417     12    1  chequing    -50.0            internet banking
# 418     12    2  chequing    -93.0            internet banking
# 419     12   31  chequing -50000.0            internet banking
# 420     12   31  chequing   7000.0          branch transaction
#
#                            type             party  index_copy
# 0                   atm deposit               NaN           0
# 1                    e-transfer  blue hockey club           1
# 2    visa debit retail purchase            presto           2
# 3    visa debit retail purchase            presto           3
# 4    visa debit retail purchase            presto           4
# ..                          ...               ...         ...
# 416  visa debit retail purchase            presto         416
# 417                  e-transfer  blue hockey club         417
# 418           internet transfer               NaN         418
# 419           internet transfer               NaN         419
# 420                 credit memo               NaN         420
#
# [421 rows x 11 columns]

# %%
def load_cibc_credit_csv(csv_path):
    credit_df = pd.read_csv(csv_path, usecols=range(0, 4), names=["date", "description", "debit", "credit"])
    return credit_df

# %%
credit_df = load_cibc_credit_csv(credit_csv_path)
credit_df
# Out:
#           date                        description  debit  credit
# 0   2025-01-07                WALMART TORONTO, ON   64.0     NaN
# 1   2025-01-07  PAYMENT THANK YOU/PAIEMEN T MERCI    NaN    64.0
# 2   2025-01-14                WALMART TORONTO, ON   80.0     NaN
# 3   2025-01-14  PAYMENT THANK YOU/PAIEMEN T MERCI    NaN    80.0
# 4   2025-01-21                WALMART TORONTO, ON   51.0     NaN
# ..         ...                                ...    ...     ...
# 91  2025-11-18  PAYMENT THANK YOU/PAIEMEN T MERCI    NaN    82.0
# 92  2025-11-25                WALMART TORONTO, ON   51.0     NaN
# 93  2025-11-25  PAYMENT THANK YOU/PAIEMEN T MERCI    NaN    51.0
# 94  2025-12-02                WALMART TORONTO, ON   93.0     NaN
# 95  2025-12-02  PAYMENT THANK YOU/PAIEMEN T MERCI    NaN    93.0
#
# [96 rows x 4 columns]

# %%
expanded_credit_df = expand_account_df(
    "credit",
    credit_df,
    expand_fn=expand_credit,
    duplicate_index=False
)
expanded_credit_df
# Out:
#           date                        description  year  month  day account  \
# 0   2025-01-07                WALMART TORONTO, ON  2025      1    7  credit
# 1   2025-01-07  PAYMENT THANK YOU/PAIEMEN T MERCI  2025      1    7  credit
# 2   2025-01-14                WALMART TORONTO, ON  2025      1   14  credit
# 3   2025-01-14  PAYMENT THANK YOU/PAIEMEN T MERCI  2025      1   14  credit
# 4   2025-01-21                WALMART TORONTO, ON  2025      1   21  credit
# ..         ...                                ...   ...    ...  ...     ...
# 91  2025-11-18  PAYMENT THANK YOU/PAIEMEN T MERCI  2025     11   18  credit
# 92  2025-11-25                WALMART TORONTO, ON  2025     11   25  credit
# 93  2025-11-25  PAYMENT THANK YOU/PAIEMEN T MERCI  2025     11   25  credit
# 94  2025-12-02                WALMART TORONTO, ON  2025     12    2  credit
# 95  2025-12-02  PAYMENT THANK YOU/PAIEMEN T MERCI  2025     12    2  credit
#
#     amount    party
# 0    -64.0  walmart
# 1     64.0      NaN
# 2    -80.0  walmart
# 3     80.0      NaN
# 4    -51.0  walmart
# ..     ...      ...
# 91    82.0      NaN
# 92   -51.0  walmart
# 93    51.0      NaN
# 94   -93.0  walmart
# 95    93.0      NaN
#
# [96 rows x 8 columns]

# %%
print(string.punctuation)
# Out:
# !"#$%&'()*+,-./:;<=>?@[\]^_`{|}~

# %%
uid_dict = {}

def create_uid(date, description, account, amount):
    separator = "_"
    table = str.maketrans("", "", string.punctuation)
    description = description.translate(table)
    uid = separator.join([date, description, account, str(amount)])
    if uid not in uid_dict:
        uid_dict[uid] = 1
    else:
        uid_dict[uid] += 1
    return separator.join([uid, str(uid_dict[uid])]).lower()

def get_uid_series(df):
    return df.apply(lambda x: create_uid(
        x["date"],
        x["description"],
        x["account"],
        x["amount"]
    ), axis=1)

# %%
expanded_savings_df["uid"] = get_uid_series(expanded_savings_df)
expanded_savings_df
# Out:
#           date                                        description  year  \
# 0   2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 1   2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 2   2025-01-31  Internet Banking E-TRANSFER 891379219227 LANDLORD  2025
# 3   2025-01-31  Internet Banking E-TRANSFER 141960766495 LANDLORD  2025
# 4   2025-01-31   Internet Banking INTERNET TRANSFER 178752671254   2025
# 5   2025-02-28  Internet Banking E-TRANSFER 899912012729 LANDLORD  2025
# 6   2025-02-28  Internet Banking E-TRANSFER 506104578856 LANDLORD  2025
# 7   2025-02-28   Internet Banking INTERNET TRANSFER 853155311571   2025
# 8   2025-03-31   Internet Banking INTERNET TRANSFER 193040394515   2025
# 9   2025-03-31  Internet Banking E-TRANSFER 204002784579 LANDLORD  2025
# 10  2025-03-31  Internet Banking E-TRANSFER 601490735807 LANDLORD  2025
# 11  2025-04-30  Internet Banking E-TRANSFER 375813354092 LANDLORD  2025
# 12  2025-04-30  Internet Banking E-TRANSFER 413576083196 LANDLORD  2025
# 13  2025-04-30   Internet Banking INTERNET TRANSFER 825950711483   2025
# 14  2025-05-31   Internet Banking INTERNET TRANSFER 354554250700   2025
# 15  2025-05-31  Internet Banking E-TRANSFER 521834751400 LANDLORD  2025
# 16  2025-05-31  Internet Banking E-TRANSFER 701657854702 LANDLORD  2025
# 17  2025-06-30   Internet Banking INTERNET TRANSFER 617707081506   2025
# 18  2025-06-30  Internet Banking E-TRANSFER 828826776261 LANDLORD  2025
# 19  2025-06-30  Internet Banking E-TRANSFER 808388247626 LANDLORD  2025
# 20  2025-07-31  Internet Banking E-TRANSFER 221695274493 LANDLORD  2025
# 21  2025-07-31  Internet Banking E-TRANSFER 775646115921 LANDLORD  2025
# 22  2025-07-31   Internet Banking INTERNET TRANSFER 757710935231   2025
# 23  2025-08-31  Internet Banking E-TRANSFER 919774316604 LANDLORD  2025
# 24  2025-08-31  Internet Banking E-TRANSFER 249074173578 LANDLORD  2025
# 25  2025-08-31   Internet Banking INTERNET TRANSFER 464886862147   2025
# 26  2025-09-30  Internet Banking E-TRANSFER 277777142749 LANDLORD  2025
# 27  2025-09-30   Internet Banking INTERNET TRANSFER 786873531098   2025
# 28  2025-09-30  Internet Banking E-TRANSFER 149029665899 LANDLORD  2025
# 29  2025-10-31  Internet Banking E-TRANSFER 722900186038 LANDLORD  2025
# 30  2025-10-31  Internet Banking E-TRANSFER 688677006633 LANDLORD  2025
# 31  2025-10-31   Internet Banking INTERNET TRANSFER 127344273120   2025
# 32  2025-11-30  Internet Banking E-TRANSFER 383532100904 LANDLORD  2025
# 33  2025-11-30  Internet Banking E-TRANSFER 093192064969 LANDLORD  2025
# 34  2025-11-30   Internet Banking INTERNET TRANSFER 741515855447   2025
# 35  2025-12-31  Internet Banking E-TRANSFER 149174661918 LANDLORD  2025
# 36  2025-12-31  Internet Banking E-TRANSFER 483520204193 LANDLORD  2025
# 37  2025-12-31   Internet Banking INTERNET TRANSFER 790268759218   2025
#
#     month  day  account   amount                     method  \
# 0       1    1  savings   2000.0  automated banking machine
# 1       1    1  savings   2000.0  automated banking machine
# 2       1   31  savings  -1500.0           internet banking
# 3       1   31  savings   -256.0           internet banking
# 4       1   31  savings  50000.0           internet banking
# 5       2   28  savings  -1500.0           internet banking
# 6       2   28  savings   -259.0           internet banking
# 7       2   28  savings  50000.0           internet banking
# 8       3   31  savings  50000.0           internet banking
# 9       3   31  savings  -1500.0           internet banking
# 10      3   31  savings   -271.0           internet banking
# 11      4   30  savings  -1500.0           internet banking
# 12      4   30  savings   -275.0           internet banking
# 13      4   30  savings  50000.0           internet banking
# 14      5   31  savings  50000.0           internet banking
# 15      5   31  savings  -1500.0           internet banking
# 16      5   31  savings   -282.0           internet banking
# 17      6   30  savings  50000.0           internet banking
# 18      6   30  savings   -283.0           internet banking
# 19      6   30  savings  -1500.0           internet banking
# 20      7   31  savings  -1500.0           internet banking
# 21      7   31  savings   -277.0           internet banking
# 22      7   31  savings  50000.0           internet banking
# 23      8   31  savings  -1500.0           internet banking
# 24      8   31  savings   -280.0           internet banking
# 25      8   31  savings  50000.0           internet banking
# 26      9   30  savings   -254.0           internet banking
# 27      9   30  savings  50000.0           internet banking
# 28      9   30  savings  -1500.0           internet banking
# 29     10   31  savings  -1500.0           internet banking
# 30     10   31  savings   -275.0           internet banking
# 31     10   31  savings  50000.0           internet banking
# 32     11   30  savings  -1500.0           internet banking
# 33     11   30  savings   -299.0           internet banking
# 34     11   30  savings  50000.0           internet banking
# 35     12   31  savings   -255.0           internet banking
# 36     12   31  savings  -1500.0           internet banking
# 37     12   31  savings  50000.0           internet banking
#
#                  type     party  index_copy  \
# 0         atm deposit       NaN           0
# 1         atm deposit       NaN           1
# 2          e-transfer  landlord           2
# 3          e-transfer  landlord           3
# 4   internet transfer       NaN           4
# 5          e-transfer  landlord           5
# 6          e-transfer  landlord           6
# 7   internet transfer       NaN           7
# 8   internet transfer       NaN           8
# 9          e-transfer  landlord           9
# 10         e-transfer  landlord          10
# 11         e-transfer  landlord          11
# 12         e-transfer  landlord          12
# 13  internet transfer       NaN          13
# 14  internet transfer       NaN          14
# 15         e-transfer  landlord          15
# 16         e-transfer  landlord          16
# 17  internet transfer       NaN          17
# 18         e-transfer  landlord          18
# 19         e-transfer  landlord          19
# 20         e-transfer  landlord          20
# 21         e-transfer  landlord          21
# 22  internet transfer       NaN          22
# 23         e-transfer  landlord          23
# 24         e-transfer  landlord          24
# 25  internet transfer       NaN          25
# 26         e-transfer  landlord          26
# 27  internet transfer       NaN          27
# 28         e-transfer  landlord          28
# 29         e-transfer  landlord          29
# 30         e-transfer  landlord          30
# 31  internet transfer       NaN          31
# 32         e-transfer  landlord          32
# 33         e-transfer  landlord          33
# 34  internet transfer       NaN          34
# 35         e-transfer  landlord          35
# 36         e-transfer  landlord          36
# 37  internet transfer       NaN          37
#
#                                                   uid
# 0   2025-01-01_automated banking machine atm depos...
# 1   2025-01-01_automated banking machine atm depos...
# 2   2025-01-31_internet banking etransfer 89137921...
# 3   2025-01-31_internet banking etransfer 14196076...
# 4   2025-01-31_internet banking internet transfer ...
# 5   2025-02-28_internet banking etransfer 89991201...
# 6   2025-02-28_internet banking etransfer 50610457...
# 7   2025-02-28_internet banking internet transfer ...
# 8   2025-03-31_internet banking internet transfer ...
# 9   2025-03-31_internet banking etransfer 20400278...
# 10  2025-03-31_internet banking etransfer 60149073...
# 11  2025-04-30_internet banking etransfer 37581335...
# 12  2025-04-30_internet banking etransfer 41357608...
# 13  2025-04-30_internet banking internet transfer ...
# 14  2025-05-31_internet banking internet transfer ...
# 15  2025-05-31_internet banking etransfer 52183475...
# 16  2025-05-31_internet banking etransfer 70165785...
# 17  2025-06-30_internet banking internet transfer ...
# 18  2025-06-30_internet banking etransfer 82882677...
# 19  2025-06-30_internet banking etransfer 80838824...
# 20  2025-07-31_internet banking etransfer 22169527...
# 21  2025-07-31_internet banking etransfer 77564611...
# 22  2025-07-31_internet banking internet transfer ...
# 23  2025-08-31_internet banking etransfer 91977431...
# 24  2025-08-31_internet banking etransfer 24907417...
# 25  2025-08-31_internet banking internet transfer ...
# 26  2025-09-30_internet banking etransfer 27777714...
# 27  2025-09-30_internet banking internet transfer ...
# 28  2025-09-30_internet banking etransfer 14902966...
# 29  2025-10-31_internet banking etransfer 72290018...
# 30  2025-10-31_internet banking etransfer 68867700...
# 31  2025-10-31_internet banking internet transfer ...
# 32  2025-11-30_internet banking etransfer 38353210...
# 33  2025-11-30_internet banking etransfer 09319206...
# 34  2025-11-30_internet banking internet transfer ...
# 35  2025-12-31_internet banking etransfer 14917466...
# 36  2025-12-31_internet banking etransfer 48352020...
# 37  2025-12-31_internet banking internet transfer ...

# %%
expanded_chequing_df["uid"] = get_uid_series(expanded_chequing_df)
expanded_chequing_df
# Out:
#            date                                        description  year  \
# 0    2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 1    2025-01-01  Internet Banking E-TRANSFER 349282506970 BLUE ...  2025
# 2    2025-01-02  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# 3    2025-01-03  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# 4    2025-01-04  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# ..          ...                                                ...   ...
# 416  2025-12-01  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# 417  2025-12-01  Internet Banking E-TRANSFER 917263704293 BLUE ...  2025
# 418  2025-12-02   Internet Banking INTERNET TRANSFER 532904682993   2025
# 419  2025-12-31   Internet Banking INTERNET TRANSFER 790268759218   2025
# 420  2025-12-31                    Branch Transaction CREDIT MEMO   2025
#
#      month  day   account   amount                      method  \
# 0        1    1  chequing   2000.0   automated banking machine
# 1        1    1  chequing    -50.0            internet banking
# 2        1    2  chequing     -3.0  point of sale - visa debit
# 3        1    3  chequing     -9.0  point of sale - visa debit
# 4        1    4  chequing     -9.0  point of sale - visa debit
# ..     ...  ...       ...      ...                         ...
# 416     12    1  chequing     -4.0  point of sale - visa debit
# 417     12    1  chequing    -50.0            internet banking
# 418     12    2  chequing    -93.0            internet banking
# 419     12   31  chequing -50000.0            internet banking
# 420     12   31  chequing   7000.0          branch transaction
#
#                            type             party  index_copy  \
# 0                   atm deposit               NaN           0
# 1                    e-transfer  blue hockey club           1
# 2    visa debit retail purchase            presto           2
# 3    visa debit retail purchase            presto           3
# 4    visa debit retail purchase            presto           4
# ..                          ...               ...         ...
# 416  visa debit retail purchase            presto         416
# 417                  e-transfer  blue hockey club         417
# 418           internet transfer               NaN         418
# 419           internet transfer               NaN         419
# 420                 credit memo               NaN         420
#
#                                                    uid
# 0    2025-01-01_automated banking machine atm depos...
# 1    2025-01-01_internet banking etransfer 34928250...
# 2    2025-01-02_point of sale  visa debit visa debi...
# 3    2025-01-03_point of sale  visa debit visa debi...
# 4    2025-01-04_point of sale  visa debit visa debi...
# ..                                                 ...
# 416  2025-12-01_point of sale  visa debit visa debi...
# 417  2025-12-01_internet banking etransfer 91726370...
# 418  2025-12-02_internet banking internet transfer ...
# 419  2025-12-31_internet banking internet transfer ...
# 420  2025-12-31_branch transaction credit memo _che...
#
# [421 rows x 12 columns]

# %%
expanded_credit_df["uid"] = get_uid_series(expanded_credit_df)
expanded_credit_df
# Out:
#           date                        description  year  month  day account  \
# 0   2025-01-07                WALMART TORONTO, ON  2025      1    7  credit
# 1   2025-01-07  PAYMENT THANK YOU/PAIEMEN T MERCI  2025      1    7  credit
# 2   2025-01-14                WALMART TORONTO, ON  2025      1   14  credit
# 3   2025-01-14  PAYMENT THANK YOU/PAIEMEN T MERCI  2025      1   14  credit
# 4   2025-01-21                WALMART TORONTO, ON  2025      1   21  credit
# ..         ...                                ...   ...    ...  ...     ...
# 91  2025-11-18  PAYMENT THANK YOU/PAIEMEN T MERCI  2025     11   18  credit
# 92  2025-11-25                WALMART TORONTO, ON  2025     11   25  credit
# 93  2025-11-25  PAYMENT THANK YOU/PAIEMEN T MERCI  2025     11   25  credit
# 94  2025-12-02                WALMART TORONTO, ON  2025     12    2  credit
# 95  2025-12-02  PAYMENT THANK YOU/PAIEMEN T MERCI  2025     12    2  credit
#
#     amount    party                                                uid
# 0    -64.0  walmart       2025-01-07_walmart toronto on_credit_-64.0_1
# 1     64.0      NaN  2025-01-07_payment thank youpaiemen t merci_cr...
# 2    -80.0  walmart       2025-01-14_walmart toronto on_credit_-80.0_1
# 3     80.0      NaN  2025-01-14_payment thank youpaiemen t merci_cr...
# 4    -51.0  walmart       2025-01-21_walmart toronto on_credit_-51.0_1
# ..     ...      ...                                                ...
# 91    82.0      NaN  2025-11-18_payment thank youpaiemen t merci_cr...
# 92   -51.0  walmart       2025-11-25_walmart toronto on_credit_-51.0_1
# 93    51.0      NaN  2025-11-25_payment thank youpaiemen t merci_cr...
# 94   -93.0  walmart       2025-12-02_walmart toronto on_credit_-93.0_1
# 95    93.0      NaN  2025-12-02_payment thank youpaiemen t merci_cr...
#
# [96 rows x 9 columns]

# %%
merged_df = expanded_savings_df.merge(expanded_chequing_df, left_on="description", right_on="description")
merged_df = merged_df.loc[merged_df["amount_x"] == -1 * merged_df["amount_y"]]
merged_df
# Out:
#         date_x                                       description  year_x  \
# 2   2025-01-31  Internet Banking INTERNET TRANSFER 178752671254     2025
# 3   2025-02-28  Internet Banking INTERNET TRANSFER 853155311571     2025
# 4   2025-03-31  Internet Banking INTERNET TRANSFER 193040394515     2025
# 5   2025-04-30  Internet Banking INTERNET TRANSFER 825950711483     2025
# 6   2025-05-31  Internet Banking INTERNET TRANSFER 354554250700     2025
# 7   2025-06-30  Internet Banking INTERNET TRANSFER 617707081506     2025
# 8   2025-07-31  Internet Banking INTERNET TRANSFER 757710935231     2025
# 9   2025-08-31  Internet Banking INTERNET TRANSFER 464886862147     2025
# 10  2025-09-30  Internet Banking INTERNET TRANSFER 786873531098     2025
# 11  2025-10-31  Internet Banking INTERNET TRANSFER 127344273120     2025
# 12  2025-11-30  Internet Banking INTERNET TRANSFER 741515855447     2025
# 13  2025-12-31  Internet Banking INTERNET TRANSFER 790268759218     2025
#
#     month_x  day_x account_x  amount_x          method_x             type_x  \
# 2         1     31   savings   50000.0  internet banking  internet transfer
# 3         2     28   savings   50000.0  internet banking  internet transfer
# 4         3     31   savings   50000.0  internet banking  internet transfer
# 5         4     30   savings   50000.0  internet banking  internet transfer
# 6         5     31   savings   50000.0  internet banking  internet transfer
# 7         6     30   savings   50000.0  internet banking  internet transfer
# 8         7     31   savings   50000.0  internet banking  internet transfer
# 9         8     31   savings   50000.0  internet banking  internet transfer
# 10        9     30   savings   50000.0  internet banking  internet transfer
# 11       10     31   savings   50000.0  internet banking  internet transfer
# 12       11     30   savings   50000.0  internet banking  internet transfer
# 13       12     31   savings   50000.0  internet banking  internet transfer
#
#    party_x  ...  year_y month_y day_y  account_y  amount_y          method_y  \
# 2      NaN  ...    2025       1    31   chequing  -50000.0  internet banking
# 3      NaN  ...    2025       2    28   chequing  -50000.0  internet banking
# 4      NaN  ...    2025       3    31   chequing  -50000.0  internet banking
# 5      NaN  ...    2025       4    30   chequing  -50000.0  internet banking
# 6      NaN  ...    2025       5    31   chequing  -50000.0  internet banking
# 7      NaN  ...    2025       6    30   chequing  -50000.0  internet banking
# 8      NaN  ...    2025       7    31   chequing  -50000.0  internet banking
# 9      NaN  ...    2025       8    31   chequing  -50000.0  internet banking
# 10     NaN  ...    2025       9    30   chequing  -50000.0  internet banking
# 11     NaN  ...    2025      10    31   chequing  -50000.0  internet banking
# 12     NaN  ...    2025      11    30   chequing  -50000.0  internet banking
# 13     NaN  ...    2025      12    31   chequing  -50000.0  internet banking
#
#                type_y  party_y index_copy_y  \
# 2   internet transfer      NaN           37
# 3   internet transfer      NaN           72
# 4   internet transfer      NaN          109
# 5   internet transfer      NaN          147
# 6   internet transfer      NaN          187
# 7   internet transfer      NaN          223
# 8   internet transfer      NaN          263
# 9   internet transfer      NaN          301
# 10  internet transfer      NaN          337
# 11  internet transfer      NaN          376
# 12  internet transfer      NaN          414
# 13  internet transfer      NaN          419
#
#                                                 uid_y
# 2   2025-01-31_internet banking internet transfer ...
# 3   2025-02-28_internet banking internet transfer ...
# 4   2025-03-31_internet banking internet transfer ...
# 5   2025-04-30_internet banking internet transfer ...
# 6   2025-05-31_internet banking internet transfer ...
# 7   2025-06-30_internet banking internet transfer ...
# 8   2025-07-31_internet banking internet transfer ...
# 9   2025-08-31_internet banking internet transfer ...
# 10  2025-09-30_internet banking internet transfer ...
# 11  2025-10-31_internet banking internet transfer ...
# 12  2025-11-30_internet banking internet transfer ...
# 13  2025-12-31_internet banking internet transfer ...
#
# [12 rows x 23 columns]

# %%
internal_transfer_df = pd.concat([
    expanded_savings_df.loc[merged_df["index_copy_x"]],
    expanded_chequing_df.loc[merged_df["index_copy_y"]]
]).drop(columns=["index_copy", "party"]).sort_values(by=["uid"]).reset_index(drop=True)
internal_transfer_df
# Out:
#           date                                       description  year  month  \
# 0   2025-01-31  Internet Banking INTERNET TRANSFER 178752671254   2025      1
# 1   2025-01-31  Internet Banking INTERNET TRANSFER 178752671254   2025      1
# 2   2025-02-28  Internet Banking INTERNET TRANSFER 853155311571   2025      2
# 3   2025-02-28  Internet Banking INTERNET TRANSFER 853155311571   2025      2
# 4   2025-03-31  Internet Banking INTERNET TRANSFER 193040394515   2025      3
# 5   2025-03-31  Internet Banking INTERNET TRANSFER 193040394515   2025      3
# 6   2025-04-30  Internet Banking INTERNET TRANSFER 825950711483   2025      4
# 7   2025-04-30  Internet Banking INTERNET TRANSFER 825950711483   2025      4
# 8   2025-05-31  Internet Banking INTERNET TRANSFER 354554250700   2025      5
# 9   2025-05-31  Internet Banking INTERNET TRANSFER 354554250700   2025      5
# 10  2025-06-30  Internet Banking INTERNET TRANSFER 617707081506   2025      6
# 11  2025-06-30  Internet Banking INTERNET TRANSFER 617707081506   2025      6
# 12  2025-07-31  Internet Banking INTERNET TRANSFER 757710935231   2025      7
# 13  2025-07-31  Internet Banking INTERNET TRANSFER 757710935231   2025      7
# 14  2025-08-31  Internet Banking INTERNET TRANSFER 464886862147   2025      8
# 15  2025-08-31  Internet Banking INTERNET TRANSFER 464886862147   2025      8
# 16  2025-09-30  Internet Banking INTERNET TRANSFER 786873531098   2025      9
# 17  2025-09-30  Internet Banking INTERNET TRANSFER 786873531098   2025      9
# 18  2025-10-31  Internet Banking INTERNET TRANSFER 127344273120   2025     10
# 19  2025-10-31  Internet Banking INTERNET TRANSFER 127344273120   2025     10
# 20  2025-11-30  Internet Banking INTERNET TRANSFER 741515855447   2025     11
# 21  2025-11-30  Internet Banking INTERNET TRANSFER 741515855447   2025     11
# 22  2025-12-31  Internet Banking INTERNET TRANSFER 790268759218   2025     12
# 23  2025-12-31  Internet Banking INTERNET TRANSFER 790268759218   2025     12
#
#     day   account   amount            method               type  \
# 0    31  chequing -50000.0  internet banking  internet transfer
# 1    31   savings  50000.0  internet banking  internet transfer
# 2    28  chequing -50000.0  internet banking  internet transfer
# 3    28   savings  50000.0  internet banking  internet transfer
# 4    31  chequing -50000.0  internet banking  internet transfer
# 5    31   savings  50000.0  internet banking  internet transfer
# 6    30  chequing -50000.0  internet banking  internet transfer
# 7    30   savings  50000.0  internet banking  internet transfer
# 8    31  chequing -50000.0  internet banking  internet transfer
# 9    31   savings  50000.0  internet banking  internet transfer
# 10   30  chequing -50000.0  internet banking  internet transfer
# 11   30   savings  50000.0  internet banking  internet transfer
# 12   31  chequing -50000.0  internet banking  internet transfer
# 13   31   savings  50000.0  internet banking  internet transfer
# 14   31  chequing -50000.0  internet banking  internet transfer
# 15   31   savings  50000.0  internet banking  internet transfer
# 16   30  chequing -50000.0  internet banking  internet transfer
# 17   30   savings  50000.0  internet banking  internet transfer
# 18   31  chequing -50000.0  internet banking  internet transfer
# 19   31   savings  50000.0  internet banking  internet transfer
# 20   30  chequing -50000.0  internet banking  internet transfer
# 21   30   savings  50000.0  internet banking  internet transfer
# 22   31  chequing -50000.0  internet banking  internet transfer
# 23   31   savings  50000.0  internet banking  internet transfer
#
#                                                   uid
# 0   2025-01-31_internet banking internet transfer ...
# 1   2025-01-31_internet banking internet transfer ...
# 2   2025-02-28_internet banking internet transfer ...
# 3   2025-02-28_internet banking internet transfer ...
# 4   2025-03-31_internet banking internet transfer ...
# 5   2025-03-31_internet banking internet transfer ...
# 6   2025-04-30_internet banking internet transfer ...
# 7   2025-04-30_internet banking internet transfer ...
# 8   2025-05-31_internet banking internet transfer ...
# 9   2025-05-31_internet banking internet transfer ...
# 10  2025-06-30_internet banking internet transfer ...
# 11  2025-06-30_internet banking internet transfer ...
# 12  2025-07-31_internet banking internet transfer ...
# 13  2025-07-31_internet banking internet transfer ...
# 14  2025-08-31_internet banking internet transfer ...
# 15  2025-08-31_internet banking internet transfer ...
# 16  2025-09-30_internet banking internet transfer ...
# 17  2025-09-30_internet banking internet transfer ...
# 18  2025-10-31_internet banking internet transfer ...
# 19  2025-10-31_internet banking internet transfer ...
# 20  2025-11-30_internet banking internet transfer ...
# 21  2025-11-30_internet banking internet transfer ...
# 22  2025-12-31_internet banking internet transfer ...
# 23  2025-12-31_internet banking internet transfer ...

# %%
raw_debit_df = pd.concat([
    expanded_savings_df.drop(merged_df["index_copy_x"]),
    expanded_chequing_df.drop(merged_df["index_copy_y"])
]).drop(columns=["index_copy"]).reset_index(drop=True)
raw_debit_df
# Out:
#            date                                        description  year  \
# 0    2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 1    2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 2    2025-01-31  Internet Banking E-TRANSFER 891379219227 LANDLORD  2025
# 3    2025-01-31  Internet Banking E-TRANSFER 141960766495 LANDLORD  2025
# 4    2025-02-28  Internet Banking E-TRANSFER 899912012729 LANDLORD  2025
# ..          ...                                                ...   ...
# 430  2025-11-30  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# 431  2025-12-01  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# 432  2025-12-01  Internet Banking E-TRANSFER 917263704293 BLUE ...  2025
# 433  2025-12-02   Internet Banking INTERNET TRANSFER 532904682993   2025
# 434  2025-12-31                    Branch Transaction CREDIT MEMO   2025
#
#      month  day   account  amount                      method  \
# 0        1    1   savings  2000.0   automated banking machine
# 1        1    1   savings  2000.0   automated banking machine
# 2        1   31   savings -1500.0            internet banking
# 3        1   31   savings  -256.0            internet banking
# 4        2   28   savings -1500.0            internet banking
# ..     ...  ...       ...     ...                         ...
# 430     11   30  chequing    -8.0  point of sale - visa debit
# 431     12    1  chequing    -4.0  point of sale - visa debit
# 432     12    1  chequing   -50.0            internet banking
# 433     12    2  chequing   -93.0            internet banking
# 434     12   31  chequing  7000.0          branch transaction
#
#                            type             party  \
# 0                   atm deposit               NaN
# 1                   atm deposit               NaN
# 2                    e-transfer          landlord
# 3                    e-transfer          landlord
# 4                    e-transfer          landlord
# ..                          ...               ...
# 430  visa debit retail purchase            presto
# 431  visa debit retail purchase            presto
# 432                  e-transfer  blue hockey club
# 433           internet transfer               NaN
# 434                 credit memo               NaN
#
#                                                    uid
# 0    2025-01-01_automated banking machine atm depos...
# 1    2025-01-01_automated banking machine atm depos...
# 2    2025-01-31_internet banking etransfer 89137921...
# 3    2025-01-31_internet banking etransfer 14196076...
# 4    2025-02-28_internet banking etransfer 89991201...
# ..                                                 ...
# 430  2025-11-30_point of sale  visa debit visa debi...
# 431  2025-12-01_point of sale  visa debit visa debi...
# 432  2025-12-01_internet banking etransfer 91726370...
# 433  2025-12-02_internet banking internet transfer ...
# 434  2025-12-31_branch transaction credit memo _che...
#
# [435 rows x 11 columns]

# %%
internal_payment_from_debit_df = raw_debit_df.loc[
    (raw_debit_df["method"] == "internet banking") &
    (raw_debit_df["type"] == "internet transfer")
].drop(columns=["party"])
internal_payment_from_debit_df
# Out:
#            date                                       description  year  \
# 35   2025-01-07  Internet Banking INTERNET TRANSFER 755558011330   2025
# 43   2025-01-14  Internet Banking INTERNET TRANSFER 996991902804   2025
# 51   2025-01-21  Internet Banking INTERNET TRANSFER 986463128183   2025
# 59   2025-01-28  Internet Banking INTERNET TRANSFER 089849535459   2025
# 69   2025-02-04  Internet Banking INTERNET TRANSFER 858247631127   2025
# 77   2025-02-11  Internet Banking INTERNET TRANSFER 701548196466   2025
# 84   2025-02-18  Internet Banking INTERNET TRANSFER 985272724725   2025
# 92   2025-02-25  Internet Banking INTERNET TRANSFER 722097679043   2025
# 102  2025-03-04  Internet Banking INTERNET TRANSFER 761892470662   2025
# 111  2025-03-11  Internet Banking INTERNET TRANSFER 120658481851   2025
# 117  2025-03-18  Internet Banking INTERNET TRANSFER 361980431392   2025
# 127  2025-03-25  Internet Banking INTERNET TRANSFER 684694646636   2025
# 137  2025-04-01  Internet Banking INTERNET TRANSFER 901224184083   2025
# 143  2025-04-08  Internet Banking INTERNET TRANSFER 891047739187   2025
# 153  2025-04-15  Internet Banking INTERNET TRANSFER 525807877131   2025
# 161  2025-04-22  Internet Banking INTERNET TRANSFER 915525559026   2025
# 169  2025-04-29  Internet Banking INTERNET TRANSFER 467471545523   2025
# 179  2025-05-06  Internet Banking INTERNET TRANSFER 960020711815   2025
# 186  2025-05-13  Internet Banking INTERNET TRANSFER 301660020614   2025
# 194  2025-05-20  Internet Banking INTERNET TRANSFER 642579926973   2025
# 203  2025-05-27  Internet Banking INTERNET TRANSFER 070778887302   2025
# 211  2025-06-03  Internet Banking INTERNET TRANSFER 808938541512   2025
# 221  2025-06-10  Internet Banking INTERNET TRANSFER 434406615367   2025
# 229  2025-06-17  Internet Banking INTERNET TRANSFER 800460679262   2025
# 237  2025-06-24  Internet Banking INTERNET TRANSFER 249989644416   2025
# 246  2025-07-01  Internet Banking INTERNET TRANSFER 531228080211   2025
# 255  2025-07-08  Internet Banking INTERNET TRANSFER 764044855591   2025
# 263  2025-07-15  Internet Banking INTERNET TRANSFER 502855122654   2025
# 271  2025-07-22  Internet Banking INTERNET TRANSFER 964766664434   2025
# 279  2025-07-29  Internet Banking INTERNET TRANSFER 836821742202   2025
# 289  2025-08-05  Internet Banking INTERNET TRANSFER 315148263053   2025
# 297  2025-08-12  Internet Banking INTERNET TRANSFER 710335176896   2025
# 305  2025-08-19  Internet Banking INTERNET TRANSFER 764804113123   2025
# 313  2025-08-26  Internet Banking INTERNET TRANSFER 798525039077   2025
# 323  2025-09-02  Internet Banking INTERNET TRANSFER 180931347965   2025
# 330  2025-09-09  Internet Banking INTERNET TRANSFER 421636728391   2025
# 339  2025-09-16  Internet Banking INTERNET TRANSFER 871369200366   2025
# 347  2025-09-23  Internet Banking INTERNET TRANSFER 587758844661   2025
# 355  2025-09-30  Internet Banking INTERNET TRANSFER 224296418551   2025
# 365  2025-10-07  Internet Banking INTERNET TRANSFER 633500242315   2025
# 373  2025-10-14  Internet Banking INTERNET TRANSFER 898204474908   2025
# 380  2025-10-21  Internet Banking INTERNET TRANSFER 026744446038   2025
# 388  2025-10-28  Internet Banking INTERNET TRANSFER 360497880126   2025
# 397  2025-11-04  Internet Banking INTERNET TRANSFER 090693565103   2025
# 406  2025-11-11  Internet Banking INTERNET TRANSFER 491234612422   2025
# 414  2025-11-18  Internet Banking INTERNET TRANSFER 757393494756   2025
# 423  2025-11-25  Internet Banking INTERNET TRANSFER 321821919755   2025
# 433  2025-12-02  Internet Banking INTERNET TRANSFER 532904682993   2025
#
#      month  day   account  amount            method               type  \
# 35       1    7  chequing   -64.0  internet banking  internet transfer
# 43       1   14  chequing   -80.0  internet banking  internet transfer
# 51       1   21  chequing   -51.0  internet banking  internet transfer
# 59       1   28  chequing   -80.0  internet banking  internet transfer
# 69       2    4  chequing   -74.0  internet banking  internet transfer
# 77       2   11  chequing   -75.0  internet banking  internet transfer
# 84       2   18  chequing   -51.0  internet banking  internet transfer
# 92       2   25  chequing   -90.0  internet banking  internet transfer
# 102      3    4  chequing   -67.0  internet banking  internet transfer
# 111      3   11  chequing   -83.0  internet banking  internet transfer
# 117      3   18  chequing   -85.0  internet banking  internet transfer
# 127      3   25  chequing   -72.0  internet banking  internet transfer
# 137      4    1  chequing   -76.0  internet banking  internet transfer
# 143      4    8  chequing   -68.0  internet banking  internet transfer
# 153      4   15  chequing   -56.0  internet banking  internet transfer
# 161      4   22  chequing  -100.0  internet banking  internet transfer
# 169      4   29  chequing   -84.0  internet banking  internet transfer
# 179      5    6  chequing   -91.0  internet banking  internet transfer
# 186      5   13  chequing   -67.0  internet banking  internet transfer
# 194      5   20  chequing   -63.0  internet banking  internet transfer
# 203      5   27  chequing   -93.0  internet banking  internet transfer
# 211      6    3  chequing   -50.0  internet banking  internet transfer
# 221      6   10  chequing   -57.0  internet banking  internet transfer
# 229      6   17  chequing   -88.0  internet banking  internet transfer
# 237      6   24  chequing   -59.0  internet banking  internet transfer
# 246      7    1  chequing   -68.0  internet banking  internet transfer
# 255      7    8  chequing   -66.0  internet banking  internet transfer
# 263      7   15  chequing   -56.0  internet banking  internet transfer
# 271      7   22  chequing   -63.0  internet banking  internet transfer
# 279      7   29  chequing   -97.0  internet banking  internet transfer
# 289      8    5  chequing   -80.0  internet banking  internet transfer
# 297      8   12  chequing   -81.0  internet banking  internet transfer
# 305      8   19  chequing   -50.0  internet banking  internet transfer
# 313      8   26  chequing   -95.0  internet banking  internet transfer
# 323      9    2  chequing   -86.0  internet banking  internet transfer
# 330      9    9  chequing   -62.0  internet banking  internet transfer
# 339      9   16  chequing   -99.0  internet banking  internet transfer
# 347      9   23  chequing   -54.0  internet banking  internet transfer
# 355      9   30  chequing   -56.0  internet banking  internet transfer
# 365     10    7  chequing   -96.0  internet banking  internet transfer
# 373     10   14  chequing   -92.0  internet banking  internet transfer
# 380     10   21  chequing   -60.0  internet banking  internet transfer
# 388     10   28  chequing   -69.0  internet banking  internet transfer
# 397     11    4  chequing   -63.0  internet banking  internet transfer
# 406     11   11  chequing   -50.0  internet banking  internet transfer
# 414     11   18  chequing   -82.0  internet banking  internet transfer
# 423     11   25  chequing   -51.0  internet banking  internet transfer
# 433     12    2  chequing   -93.0  internet banking  internet transfer
#
#                                                    uid
# 35   2025-01-07_internet banking internet transfer ...
# 43   2025-01-14_internet banking internet transfer ...
# 51   2025-01-21_internet banking internet transfer ...
# 59   2025-01-28_internet banking internet transfer ...
# 69   2025-02-04_internet banking internet transfer ...
# 77   2025-02-11_internet banking internet transfer ...
# 84   2025-02-18_internet banking internet transfer ...
# 92   2025-02-25_internet banking internet transfer ...
# 102  2025-03-04_internet banking internet transfer ...
# 111  2025-03-11_internet banking internet transfer ...
# 117  2025-03-18_internet banking internet transfer ...
# 127  2025-03-25_internet banking internet transfer ...
# 137  2025-04-01_internet banking internet transfer ...
# 143  2025-04-08_internet banking internet transfer ...
# 153  2025-04-15_internet banking internet transfer ...
# 161  2025-04-22_internet banking internet transfer ...
# 169  2025-04-29_internet banking internet transfer ...
# 179  2025-05-06_internet banking internet transfer ...
# 186  2025-05-13_internet banking internet transfer ...
# 194  2025-05-20_internet banking internet transfer ...
# 203  2025-05-27_internet banking internet transfer ...
# 211  2025-06-03_internet banking internet transfer ...
# 221  2025-06-10_internet banking internet transfer ...
# 229  2025-06-17_internet banking internet transfer ...
# 237  2025-06-24_internet banking internet transfer ...
# 246  2025-07-01_internet banking internet transfer ...
# 255  2025-07-08_internet banking internet transfer ...
# 263  2025-07-15_internet banking internet transfer ...
# 271  2025-07-22_internet banking internet transfer ...
# 279  2025-07-29_internet banking internet transfer ...
# 289  2025-08-05_internet banking internet transfer ...
# 297  2025-08-12_internet banking internet transfer ...
# 305  2025-08-19_internet banking internet transfer ...
# 313  2025-08-26_internet banking internet transfer ...
# 323  2025-09-02_internet banking internet transfer ...
# 330  2025-09-09_internet banking internet transfer ...
# 339  2025-09-16_internet banking internet transfer ...
# 347  2025-09-23_internet banking internet transfer ...
# 355  2025-09-30_internet banking internet transfer ...
# 365  2025-10-07_internet banking internet transfer ...
# 373  2025-10-14_internet banking internet transfer ...
# 380  2025-10-21_internet banking internet transfer ...
# 388  2025-10-28_internet banking internet transfer ...
# 397  2025-11-04_internet banking internet transfer ...
# 406  2025-11-11_internet banking internet transfer ...
# 414  2025-11-18_internet banking internet transfer ...
# 423  2025-11-25_internet banking internet transfer ...
# 433  2025-12-02_internet banking internet transfer ...

# %%
credit_payment_bool_series = expanded_credit_df["description"].str.contains("PAYMENT THANK YOU")

# %%
internal_payment_df = pd.concat([
    internal_payment_from_debit_df,
    expanded_credit_df.loc[credit_payment_bool_series]
]).drop(columns=["party"]).sort_values(by=["uid"]).reset_index(drop=True)
internal_payment_df
# Out:
#           date                                       description  year  month  \
# 0   2025-01-07  Internet Banking INTERNET TRANSFER 755558011330   2025      1
# 1   2025-01-07                 PAYMENT THANK YOU/PAIEMEN T MERCI  2025      1
# 2   2025-01-14  Internet Banking INTERNET TRANSFER 996991902804   2025      1
# 3   2025-01-14                 PAYMENT THANK YOU/PAIEMEN T MERCI  2025      1
# 4   2025-01-21  Internet Banking INTERNET TRANSFER 986463128183   2025      1
# ..         ...                                               ...   ...    ...
# 91  2025-11-18                 PAYMENT THANK YOU/PAIEMEN T MERCI  2025     11
# 92  2025-11-25  Internet Banking INTERNET TRANSFER 321821919755   2025     11
# 93  2025-11-25                 PAYMENT THANK YOU/PAIEMEN T MERCI  2025     11
# 94  2025-12-02  Internet Banking INTERNET TRANSFER 532904682993   2025     12
# 95  2025-12-02                 PAYMENT THANK YOU/PAIEMEN T MERCI  2025     12
#
#     day   account  amount            method               type  \
# 0     7  chequing   -64.0  internet banking  internet transfer
# 1     7    credit    64.0               NaN                NaN
# 2    14  chequing   -80.0  internet banking  internet transfer
# 3    14    credit    80.0               NaN                NaN
# 4    21  chequing   -51.0  internet banking  internet transfer
# ..  ...       ...     ...               ...                ...
# 91   18    credit    82.0               NaN                NaN
# 92   25  chequing   -51.0  internet banking  internet transfer
# 93   25    credit    51.0               NaN                NaN
# 94    2  chequing   -93.0  internet banking  internet transfer
# 95    2    credit    93.0               NaN                NaN
#
#                                                   uid
# 0   2025-01-07_internet banking internet transfer ...
# 1   2025-01-07_payment thank youpaiemen t merci_cr...
# 2   2025-01-14_internet banking internet transfer ...
# 3   2025-01-14_payment thank youpaiemen t merci_cr...
# 4   2025-01-21_internet banking internet transfer ...
# ..                                                ...
# 91  2025-11-18_payment thank youpaiemen t merci_cr...
# 92  2025-11-25_internet banking internet transfer ...
# 93  2025-11-25_payment thank youpaiemen t merci_cr...
# 94  2025-12-02_internet banking internet transfer ...
# 95  2025-12-02_payment thank youpaiemen t merci_cr...
#
# [96 rows x 10 columns]

# %%
debit_df = raw_debit_df.drop(internal_payment_from_debit_df.index).reset_index(drop=True)
debit_df
# Out:
#            date                                        description  year  \
# 0    2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 1    2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 2    2025-01-31  Internet Banking E-TRANSFER 891379219227 LANDLORD  2025
# 3    2025-01-31  Internet Banking E-TRANSFER 141960766495 LANDLORD  2025
# 4    2025-02-28  Internet Banking E-TRANSFER 899912012729 LANDLORD  2025
# ..          ...                                                ...   ...
# 382  2025-11-30                    Branch Transaction CREDIT MEMO   2025
# 383  2025-11-30  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# 384  2025-12-01  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# 385  2025-12-01  Internet Banking E-TRANSFER 917263704293 BLUE ...  2025
# 386  2025-12-31                    Branch Transaction CREDIT MEMO   2025
#
#      month  day   account  amount                      method  \
# 0        1    1   savings  2000.0   automated banking machine
# 1        1    1   savings  2000.0   automated banking machine
# 2        1   31   savings -1500.0            internet banking
# 3        1   31   savings  -256.0            internet banking
# 4        2   28   savings -1500.0            internet banking
# ..     ...  ...       ...     ...                         ...
# 382     11   30  chequing  7000.0          branch transaction
# 383     11   30  chequing    -8.0  point of sale - visa debit
# 384     12    1  chequing    -4.0  point of sale - visa debit
# 385     12    1  chequing   -50.0            internet banking
# 386     12   31  chequing  7000.0          branch transaction
#
#                            type             party  \
# 0                   atm deposit               NaN
# 1                   atm deposit               NaN
# 2                    e-transfer          landlord
# 3                    e-transfer          landlord
# 4                    e-transfer          landlord
# ..                          ...               ...
# 382                 credit memo               NaN
# 383  visa debit retail purchase            presto
# 384  visa debit retail purchase            presto
# 385                  e-transfer  blue hockey club
# 386                 credit memo               NaN
#
#                                                    uid
# 0    2025-01-01_automated banking machine atm depos...
# 1    2025-01-01_automated banking machine atm depos...
# 2    2025-01-31_internet banking etransfer 89137921...
# 3    2025-01-31_internet banking etransfer 14196076...
# 4    2025-02-28_internet banking etransfer 89991201...
# ..                                                 ...
# 382  2025-11-30_branch transaction credit memo _che...
# 383  2025-11-30_point of sale  visa debit visa debi...
# 384  2025-12-01_point of sale  visa debit visa debi...
# 385  2025-12-01_internet banking etransfer 91726370...
# 386  2025-12-31_branch transaction credit memo _che...
#
# [387 rows x 11 columns]

# %%
def get_sign(amount):
    if amount > 0:
        return "income"
    elif amount < 0:
        return "expense"
    return "zero-value"

# %%
cash_flow_df = pd.concat([
    debit_df,
    expanded_credit_df.loc[~credit_payment_bool_series]
]).sort_values(by=["uid"]).reset_index(drop=True)
cash_flow_df["sign"] = cash_flow_df["amount"].apply(get_sign)
cash_flow_df
# Out:
#            date                                        description  year  \
# 0    2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 1    2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 2    2025-01-01      Automated Banking Machine ATM DEPOSIT TORONTO  2025
# 3    2025-01-01  Internet Banking E-TRANSFER 349282506970 BLUE ...  2025
# 4    2025-01-02  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# ..          ...                                                ...   ...
# 430  2025-12-01  Point of Sale - Visa Debit VISA DEBIT RETAIL P...  2025
# 431  2025-12-02                                WALMART TORONTO, ON  2025
# 432  2025-12-31                    Branch Transaction CREDIT MEMO   2025
# 433  2025-12-31  Internet Banking E-TRANSFER 149174661918 LANDLORD  2025
# 434  2025-12-31  Internet Banking E-TRANSFER 483520204193 LANDLORD  2025
#
#      month  day   account  amount                      method  \
# 0        1    1  chequing  2000.0   automated banking machine
# 1        1    1   savings  2000.0   automated banking machine
# 2        1    1   savings  2000.0   automated banking machine
# 3        1    1  chequing   -50.0            internet banking
# 4        1    2  chequing    -3.0  point of sale - visa debit
# ..     ...  ...       ...     ...                         ...
# 430     12    1  chequing    -4.0  point of sale - visa debit
# 431     12    2    credit   -93.0                         NaN
# 432     12   31  chequing  7000.0          branch transaction
# 433     12   31   savings  -255.0            internet banking
# 434     12   31   savings -1500.0            internet banking
#
#                            type             party  \
# 0                   atm deposit               NaN
# 1                   atm deposit               NaN
# 2                   atm deposit               NaN
# 3                    e-transfer  blue hockey club
# 4    visa debit retail purchase            presto
# ..                          ...               ...
# 430  visa debit retail purchase            presto
# 431                         NaN           walmart
# 432                 credit memo               NaN
# 433                  e-transfer          landlord
# 434                  e-transfer          landlord
#
#                                                    uid     sign
# 0    2025-01-01_automated banking machine atm depos...   income
# 1    2025-01-01_automated banking machine atm depos...   income
# 2    2025-01-01_automated banking machine atm depos...   income
# 3    2025-01-01_internet banking etransfer 34928250...  expense
# 4    2025-01-02_point of sale  visa debit visa debi...  expense
# ..                                                 ...      ...
# 430  2025-12-01_point of sale  visa debit visa debi...  expense
# 431       2025-12-02_walmart toronto on_credit_-93.0_1  expense
# 432  2025-12-31_branch transaction credit memo _che...   income
# 433  2025-12-31_internet banking etransfer 14917466...  expense
# 434  2025-12-31_internet banking etransfer 48352020...  expense
#
# [435 rows x 12 columns]

# %%
with pd.ExcelWriter('output.xlsx') as writer:
    cash_flow_df.to_excel(writer, sheet_name="cash_flow", index=False)
    internal_transfer_df.to_excel(writer, sheet_name="internal_transfer", index=False)
    internal_payment_df.to_excel(writer, sheet_name="internal_payment", index=False)

# %% [markdown]
# ## Command Test

# %%
# db_df = pd.read_excel("C:/Users/Daniel/Documents/Git/bank-statement-cleaner/outdated.xlsx", sheet_name=None)
# db_df

# %%
# internal_payment_df.loc[~internal_payment_df["uid"].isin(db_df["internal_payment"]["uid"])]
